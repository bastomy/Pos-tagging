# %% [markdown]
# ## <center>Natural Language Processing (Tugas 2)</center>
# <strong> NIM  : 1301178418 </strong><br>
# <strong> Nama : Bastomy </strong> <br>
# <strong> Kelas : ICM-39-GAB </strong>

# %% [markdown]
# #### Deskripsi Tugas

# %% [markdown]
# Deskripsi
# Buatlah program yang mengimplementasikan dua pendekatan POS-tagging. Sebagai input adalah
# kalimat Bahasa Indonesia and output adalah kalimat setelah setiap katanya diberi tag yang tepat.
# Kedua pendekatan yang harus diimplementasikan adalah:
# 1. Baseline (menggunakan POS Tag yang paling sering muncul)
# 2. HMM.

# %% [markdown]
# ### Import library

# %%
import pandas as pd
import re
import operator

# %% [markdown]
# <strong>pandas</strong> =  untuk mempermudah membuat array menjadi data tabel <br>
# <strong>re</strong> = regular expression untuk membagi string menjadi array berdasarkan tab (\t) <br>
# <strong>operator</strong> = untuk mengambil item

# %% [markdown]
# ### Fungsi untuk membaca data training dan testing menjadi array

# %%
def read_data(train):
    dt_train = {'kata':[], 'tag':[]}
    for line in open(train):
        if not line.startswith('<kalimat') and not line.startswith('</kalimat'):
            baris = re.split(r'\t+', line.rstrip('\t'))
            dt_train['kata'].append(baris[0].lower())
            dt_train['tag'].append(baris[1].replace('\n',''))
    data = pd.DataFrame(dt_train)        
    return data

# %% [markdown]
# read_data adalah fungsi untuk membaca data .txt menjadi sebuah array <br>
# terdapat dua kolom array yaitu kata dan tag  <br>
# setiap baris data akan di looping dan di cek jika tidak berawalan <kalimat dan </kalimat maka akan lanjut ke tahap berikutnya yaitu membagi setiap baris menjadi array berdasarkan \t (Tab) <br>
# kemudian akan di simpan ke dt_train dan di set menjadi Dataframe untuk di return

# %% [markdown]
# ### Fungsi untuk menghitung jumlah tag berdasarkan kata

# %%
def post_tag_frequency(kata, data_training):
    hitungTag = data_training.loc[data_training['kata'] == kata]['tag'].value_counts()
    if(len(hitungTag) == 0):
        return 'NN','0'
    tagTerbaik = max(hitungTag.items(),key=operator.itemgetter(1))
    return tagTerbaik[0],tagTerbaik[1]

# %% [markdown]
# Menghitung jumlah tag berdasarkan kata  <br>
# variabel hitungTag akan menyimpan jumlah tag berdasarkan kata  <br>
# jika tag bernilai 0 maka akan di terun tag NN dengan jumlah 0  (untuk menghandle kata yg tidak terdaftar)<br>
# kemudian akan dicari max dari tag yg tersedia  <br>
# fungsi akan mengembalikan Tag dan jumlah tag nya <br>
# contoh (PRP   44) <br>

# %% [markdown]
# ### Fungsi prediksi tag BASELINE

# %%
def baseline(data_testing,data_training):
    index = 0 
    tag_correct = 0
    result = {'kata':[], 'prediksi':[], 'tag':[]}
    akurasi = 0
    for i in data_testing['kata']:
        tag,count = post_tag_frequency(i, data_training)
        if(tag == data_testing['tag'][index]):
            tag_correct+=1
        result['kata'].append(i)
        result['prediksi'].append(tag)
        result['tag'].append(data_testing['tag'][index])
        index+=1
    data = pd.DataFrame(result)
    akurasi = (tag_correct/index)*100
    return data,akurasi

# %% [markdown]
# Baseline akan memprediksi Tag berdasarkan kemunculan terbanyak <br>
# cara kerja fungsi diatas adalah melooping semua kata beserta Tag <br>
# kemudian kata tersebut akan diprediksi Tag nya berdasarkan data training <br>
# post_tag_frequency akan mengembalikan tag beserta jumlahnya kemunculannya, tag dari post_tag_frequency akan dijadikan prediksi <br>
# akurasi dihitung dari jumlah tag yg benar dibagi dengan total seluruh kata

# %% [markdown]
# ### Read Data

# %%
dt_training = read_data('corpus/training.txt')
dt_testing = read_data('corpus/testing.txt')

# %% [markdown]
# simpan data training dan testing kedalam variabel

# %% [markdown]
# ### NO 1. Baseline (menggunakan POS Tag yang paling sering muncul)

# %%
data, akurasi = baseline(dt_testing,dt_training)

# %% [markdown]
# Data testing dan prediksi TAG

# %%
data
# Out:
#             kata prediksi  tag
# 0     perusahaan       NN   NN
# 1          ritel       NN   NN
# 2             pt      NNP  NNP
# 3       matahari      NNP  NNP
# 4          putra       NN  NNP
# 5          prima      NNP  NNP
# 6            tbk      NNP  NNP
# 7           mppa       NN  NNP
# 8          dalam       IN   IN
# 9           tiga       CD   CD
# 10         bulan       NN   NN
# 11       pertama       OD   OD
# 12          yang       SC   SC
# 13      berakhir       VB   VB
# 14         maret      NNP  NNP
# 15          2007       CD   CD
# 16      berhasil       VB   VB
# 17        meraih       VB   VB
# 18   laba bersih       NN   NN
# 19            rp      SYM  SYM
# 20       "15,18"       NN   CD
# 21        miliar       CD   CD
# 22           ","        Z    Z
# 23          atau       CC   CC
# 24          naik       VB   VB
# 25       "24,43"       NN   CD
# 26        persen       CD   CD
# 27          dari       IN   IN
# 28            rp      SYM  SYM
# 29       "12,20"       NN   CD
# ..           ...      ...  ...
# 469      menurut       IN   IN
# 470   burhanudin      NNP  NNP
# 471    merupakan       VB   VB
# 472     indikasi       NN   NN
# 473         yang       SC   SC
# 474         baik       JJ   JJ
# 475      di mana       SC   WH
# 476     ekspansi       NN   NN
# 477         bank      NNP   NN
# 478           di       IN   IN
# 479  perkreditan       NN   NN
# 480        mulai       MD   VB
# 481     bergulir       VB   VB
# 482            .        Z    Z
# 483     ekspansi       NN   NN
# 484           di       IN   IN
# 485       bidang       NN   NN
# 486  perkreditan       NN   NN
# 487        sudah       MD   MD
# 488        mulai       MD   VB
# 489      terjadi       VB   VB
# 490          ","        Z    Z
# 491       memang       RB   RB
# 492    kecepatan       NN   NN
# 493       #name?      PRP  PRP
# 494        belum      NEG  NEG
# 495      seperti       IN   IN
# 496         kita      PRP  PRP
# 497     inginkan       NN   VB
# 498            .        Z    Z
#
# [499 rows x 3 columns]

# %% [markdown]
# Akurasi Tag (persen)

# %%
akurasi
# Out:
# 87.97595190380761

# %% [markdown]
# ### No 2 HMM

# %%
def read_file_init_table(fname):
    tag_count = {}
    tag_count['<start>'] = 0
    word_tag = {}
    tag_trans = {}
    with open(fname) as f:
        content = f.readlines()
    # you may also want to remove whitespace characters like `\n` at the end of each line
    content = [x.strip() for x in content]
    idx_line = 0
    is_first_word = 0
    
    while idx_line < len(content):
        prev_tag = '<start>'
        while not content[idx_line].startswith('</kalimat'):
            if  not content[idx_line].startswith('<kalimat'):
                content_part = content[idx_line].split('\t')
                if content_part[1] in tag_count:
                    tag_count[content_part[1]] += 1
                else:
                    tag_count[content_part[1]] = 1
                    
                current_word_tag = content_part[0]+','+content_part[1]
                if current_word_tag in word_tag:
                    word_tag[current_word_tag] += 1
                else:    
                    word_tag[current_word_tag] = 1
                    
                if is_first_word == 1:
                    current_tag_trans = '<start>,'+content_part[1]
                    is_first_word = 0
                else:
                    current_tag_trans = prev_tag+','+content_part[1]
                    
                if current_tag_trans in tag_trans:
                    tag_trans[current_tag_trans] += 1
                else:
                    tag_trans[current_tag_trans] = 1                    
                prev_tag = content_part[1]   
                
            else:
                tag_count['<start>'] += 1
                is_first_word = 1
            idx_line = idx_line + 1

        idx_line = idx_line+1       
    return tag_count, word_tag, tag_trans

# %%
tag_count, word_tag, tag_trans = read_file_init_table('corpus/training.txt')

# %%
tag_count
# Out:
# {'<start>': 1030,
#  'NN': 6464,
#  'SC': 1158,
#  'VB': 2852,
#  'NNP': 3868,
#  'JJ': 1076,
#  'RB': 562,
#  'IN': 2263,
#  'Z': 2752,
#  'CD': 2372,
#  'CC': 811,
#  'PR': 508,
#  'PRP': 706,
#  'MD': 534,
#  'FW': 421,
#  'NEG': 127,
#  'DT': 20,
#  'NND': 149,
#  'SYM': 331,
#  'RP': 18,
#  'WH': 8,
#  'OD': 98,
#  'X': 15,
#  'UH': 4}

# %%
word_tag
# Out:
# {'Kera,NN': 1,
#  'untuk,SC': 126,
#  'amankan,VB': 1,
#  'pesta olahraga,NN': 1,
#  'Pemerintah,NNP': 2,
#  'kota,NNP': 3,
#  'Delhi,NNP': 5,
#  'mengerahkan,VB': 1,
#  'monyet,NN': 12,
#  'mengusir,VB': 4,
#  'monyet-monyet,NN': 2,
#  'lain,JJ': 29,
#  'yang,SC': 538,
#  'berbadan,VB': 2,
#  'lebih,RB': 80,
#  'kecil,JJ': 14,
#  'dari,IN': 251,
#  'arena,NN': 2,
#  'Pesta Olahraga,NNP': 1,
#  'Persemakmuran,NNP': 1,
#  '.,Z': 1012,
#  'Beberapa,CD': 1,
#  'laporan,NN': 15,
#  'menyebutkan,VB': 10,
#  'setidaknya,RB': 2,
#  '10,CD': 21,
#  'ditempatkan,VB': 2,
#  'di,IN': 360,
#  'luar,NN': 5,
#  'lomba,NN': 1,
#  'dan,CC': 481,
#  'pertandingan,NN': 1,
#  'ibukota,NNP': 2,
#  'India,NNP': 6,
#  'Pemkot,NNP': 1,
#  'memiliki,VB': 20,
#  '28,CD': 6,
#  'berencana,VB': 9,
#  'mendatangkan,VB': 2,
#  'sejenis,NN': 1,
#  'negara bagian,NNP': 1,
#  'Rajasthan,NNP': 1,
#  'Jumlah,NN': 5,
#  'mencapai,VB': 97,
#  'ribuan,CD': 1,
#  '",",Z': 1393,
#  'sebagian besar,NN': 3,
#  'berada,VB': 14,
#  'kantor-kantor,NN': 1,
#  'pemerintah,NN': 52,
#  'hewan,NN': 1,
#  'ini,PR': 199,
#  'dianggap,VB': 4,
#  'mengganggu,VB': 3,
#  'ketertiban,NN': 1,
#  'umum,JJ': 9,
#  'Jenis,NN': 1,
#  'dikerahkan,VB': 3,
#  'pemkot,NN': 1,
#  'besar,JJ': 33,
#  'berekor,VB': 1,
#  'panjang,JJ': 4,
#  'wajah,NN': 1,
#  'berwarna,VB': 1,
#  'hitam,JJ': 1,
#  'Monyet,NN': 3,
#  'diikat,VB': 1,
#  'dengan,IN': 176,
#  'tali,NN': 2,
#  'pelatih,NN': 1,
#  'mengawasi,VB': 2,
#  'mereka,PRP': 23,
#  'akan,MD': 192,
#  'melepas,VB': 4,
#  'begitu,SC': 1,
#  'mendekat,VB': 1,
#  'Kantor,NNP': 6,
#  'berita,NNP': 1,
#  'AFP,NNP': 4,
#  'melaporkan,VB': 4,
#  'stadion,NN': 3,
#  'tinju,NN': 1,
#  'hockey,FW': 1,
#  'mendapatkan,VB': 3,
#  'perhatian,NN': 2,
#  'khusus,JJ': 13,
#  'karena,SC': 41,
#  'sering,RB': 3,
#  'diserbu,VB': 1,
#  'dua,CD': 21,
#  'serbuan,NN': 2,
#  '",Z': 70,
#  'tersebut,PR': 118,
#  ',,Z': 32,
#  'kata,VB': 164,
#  'Devender,NNP': 1,
#  'Prasad,NNP': 1,
#  'pejabat,NN': 3,
#  'pemerintah,NNP': 6,
#  'kepada,IN': 56,
#  'kantor berita,NNP': 3,
#  'Selama,IN': 3,
#  'bertahun-tahun,CD': 1,
#  'warga,NN': 2,
#  'Binatang,NN': 2,
#  'menaiki,VB': 1,
#  'kereta,NN': 1,
#  'metro,NN': 1,
#  'bahkan,RB': 8,
#  'berkeliaran,VB': 1,
#  'kompleks,NN': 1,
#  'gedung,NN': 1,
#  'parlemen,NN': 11,
#  'Belum,NEG': 1,
#  'lama,JJ': 2,
#  'kawanan,NN': 3,
#  'menyerbu,VB': 1,
#  'kantor,NN': 2,
#  'perdana menteri,NN': 3,
#  'departemen,NN': 3,
#  'pertahanan,NN': 1,
#  'tidak,NEG': 81,
#  'bisa,MD': 42,
#  'dibunuh,VB': 1,
#  'masyarakat,NN': 12,
#  'menganggap,VB': 2,
#  'suci,JJ': 1,
#  'Selain,CC': 1,
#  'harus,MD': 15,
#  'pemkot,NNP': 1,
#  'juga,RB': 75,
#  'kesulitan,VB': 3,
#  'mengatasi,VB': 5,
#  'wabah,NN': 1,
#  'demam berdarah,NN': 1,
#  'Curah,NN': 1,
#  'hujan,NN': 1,
#  'tinggi,JJ': 33,
#  'menyebabkan,VB': 5,
#  'banyak,CD': 22,
#  'genangan,NN': 2,
#  'tempat,NN': 5,
#  'ideal,JJ': 2,
#  'bagi,IN': 22,
#  'nyamuk,NN': 2,
#  'aedes,NNP': 1,
#  'berkembang biak,VB': 1,
#  'Pemkot,NN': 1,
#  'telah,MD': 72,
#  'menempatkan,VB': 2,
#  'ikan,NN': 1,
#  'berbagai,CD': 10,
#  'air,NN': 5,
#  'memangsa,VB': 1,
#  'telur,NN': 1,
#  'Miliarder,NN': 1,
#  'AS,NNP': 153,
#  'jamu,VB': 1,
#  'orang kaya,NN': 1,
#  'Cina,NNP': 6,
#  'Dua,CD': 3,
#  'miliarder,NN': 2,
#  'Amerika,NNP': 13,
#  'Bill,NNP': 1,
#  'Gates,NNP': 2,
#  'Warren,NNP': 1,
#  'Buffett,NNP': 2,
#  'mengadakan,VB': 3,
#  'jamuan,NN': 3,
#  'makan malam,NN': 3,
#  'Beijing,NNP': 1,
#  'sejumlah,CD': 6,
#  'orang,NN': 16,
#  'terkaya,JJ': 3,
#  'mengatakan,VB': 92,
#  'mempelajari,VB': 1,
#  'kegiatan,NN': 5,
#  'amal,NN': 5,
#  'negara,NN': 50,
#  'itu,PR': 146,
#  'Banyak,CD': 3,
#  'menduga,VB': 1,
#  'ingin,RB': 7,
#  'membujuk,VB': 2,
#  'para,DT': 9,
#  'tamu,NN': 2,
#  'agar,SC': 9,
#  'menyumbang,VB': 4,
#  'untuk,IN': 102,
#  'Kedua,CD': 3,
#  'dunia,NN': 21,
#  'sudah,MD': 32,
#  'berhasil,VB': 11,
#  'sangat,RB': 25,
#  'kaya,JJ': 2,
#  'menyumbangkan,VB': 2,
#  'separuh,CD': 1,
#  'kekayaan,NN': 3,
#  'Ada,VB': 1,
#  'kerahasiaan,NN': 1,
#  'mengenai,IN': 8,
#  'acara,NN': 6,
#  'pihak,NN': 25,
#  'penyelenggara,NN': 1,
#  'membeberkan,VB': 1,
#  'nama-nama,NN': 2,
#  'Salah satu,CD': 4,
#  'menghadiri,VB': 2,
#  'adalah,VB': 36,
#  'Chen,NNP': 1,
#  'Guangbiao,NNP': 1,
#  'seorang,NND': 6,
#  'meraup,VB': 1,
#  'bisnis,NN': 14,
#  'mendaur ulang,VB': 1,
#  'sampah,NN': 1,
#  'industri,NN': 28,
#  'bangunan,NN': 1,
#  'Dia,PRP': 21,
#  'BBC,NNP': 1,
#  'bahwa,SC': 38,
#  'dia,PRP': 56,
#  'seluruh,CD': 16,
#  'harta,NN': 1,
#  '#NAME?,PRP': 449,
#  'bila,SC': 4,
#  'meninggal,VB': 2,
#  'Beramal,VB': 1,
#  'membantu,VB': 10,
#  'menjadi,VB': 127,
#  'bagian,NN': 8,
#  'budaya,NN': 1,
#  'selama,IN': 21,
#  '5.000,CD': 1,
#  'tahun,NN': 168,
#  'Tetapi,CC': 2,
#  'resmi,JJ': 9,
#  'baru,MD': 11,
#  'dikembangkan,VB': 2,
#  'dalam,IN': 174,
#  '30,CD': 21,
#  'terakhir,JJ': 13,
#  'sejak,SC': 3,
#  'kami,PRP': 13,
#  'menerapkan,VB': 1,
#  'reformasi ekonomi,NN': 1,
#  'mulai,MD': 15,
#  'baru-baru ini,RB': 3,
#  'saja,RB': 12,
#  'memberi,VB': 4,
#  'makan,NN': 1,
#  'diri,NN': 3,
#  'sendiri,NN': 9,
#  'Menyumbangkan,VB': 1,
#  'uang,NN': 3,
#  'belum,NEG': 27,
#  'begitu,RB': 1,
#  'berkembang,VB': 4,
#  'sebaik,JJ': 2,
#  'Kalau,SC': 5,
#  'dikatakan,VB': 2,
#  'keberhasilan,NN': 2,
#  'mendorong,VB': 12,
#  'perdebatan,NN': 1,
#  'apa,SC': 2,
#  'arti,NN': 3,
#  'beramal,VB': 1,
#  'membutuhkan,VB': 5,
#  'Kisah,NN': 3,
#  'pendiri,NN': 2,
#  'Facebook,NNP': 5,
#  'dibuat,VB': 2,
#  'komik,NN': 2,
#  'Mark,NNP': 3,
#  'Zuckerberg,NNP': 6,
#  'diceritakan,VB': 1,
#  'sebuah,NND': 18,
#  'biografi,NN': 1,
#  'Komik,NN': 1,
#  'judul,NN': 3,
#  ':,Z': 5,
#  'Pencipta,NN': 1,
#  'tersedia,VB': 1,
#  'pasar,NN': 30,
#  'sebelum,SC': 42,
#  'Desember,NNP': 14,
#  '2010,CD': 4,
#  'demikian,PR': 20,
#  'pernyataan,NN': 9,
#  'penerbit,NNP': 1,
#  'Bluewater,NNP': 1,
#  'Productions,NNP': 1,
#  'Penulis,NNP': 1,
#  'Jerome,NNP': 1,
#  'Maida,NNP': 1,
#  'menyebut,VB': 1,
#  'kisah,NN': 2,
#  'mengagumkan,VB': 1,
#  'luar biasa,JJ': 2,
#  'Sebuah,NND': 1,
#  'film,NN': 7,
#  'The,NNP': 20,
#  'Social,NNP': 1,
#  'Network,NNP': 1,
#  'dirilis,VB': 1,
#  'pada,IN': 272,
#  'tanggal,NN': 11,
#  '15,CD': 18,
#  'Oktober,NNP': 29,
#  'nanti,NN': 5,
#  'Film,NN': 1,
#  'ditulis,VB': 4,
#  'oleh,IN': 87,
#  'pencipta,NN': 1,
#  'serial,NN': 1,
#  'West,NNP': 1,
#  'Wing,NNP': 1,
#  'Aaron,NNP': 1,
#  'Sorkin,NNP': 1,
#  'disutradarai,VB': 1,
#  'David,NNP': 1,
#  'Fincher,NNP': 1,
#  'pernah,MD': 7,
#  'menggarap,VB': 1,
#  'Fight,NNP': 1,
#  "',NNP": 5,
#  's,NNP': 5,
#  'Club,NNP': 1,
#  'sebenarnya,RB': 5,
#  'memperoleh,VB': 2,
#  'izin,NN': 2,
#  'Pemuda,NN': 1,
#  'berusia,VB': 7,
#  '26,CD': 6,
#  'Saya,PRP': 11,
#  'mengharapkan,VB': 5,
#  'ada,VB': 28,
#  'membuat,VB': 8,
#  'tentang,IN': 11,
#  'saya,PRP': 12,
#  'ketika,SC': 9,
#  'masih,MD': 62,
#  'hidup,VB': 1,
#  'konferensi,NN': 1,
#  'teknologi,NN': 7,
#  'Juni,NNP': 16,
#  'silam,NN': 2,
#  'Hingga,IN': 2,
#  'Juli,NNP': 13,
#  '500,CD': 5,
#  'juta,CD': 55,
#  'terdaftar,VB': 2,
#  'situs,NN': 7,
#  'jejaring,NN': 2,
#  'sosial,JJ': 3,
#  'Hanya,RB': 2,
#  'butuh,VB': 2,
#  'enam,CD': 8,
#  'kesuksesan,NN': 4,
#  'seperti,SC': 2,
#  'sekarang,NN': 5,
#  'setelah,SC': 24,
#  'meluncurkan,VB': 2,
#  'saat,SC': 5,
#  'duduk,VB': 2,
#  'sebagai,IN': 36,
#  'mahasiswa,NN': 1,
#  'Universitas,NNP': 2,
#  'Harvard,NNP': 2,
#  'September,NNP': 17,
#  'majalah,NNP': 2,
#  'Forbes,NNP': 1,
#  'memasukkan,VB': 2,
#  'daftar,NN': 2,
#  '35,CD': 6,
#  'Serikat,NNP': 7,
#  'dengan,SC': 53,
#  'total,NN': 20,
#  'diperkirakan,VB': 21,
#  'US,NNP': 8,
#  '$,SYM': 3,
#  '"6,4",CD': 4,
#  'miliar,CD': 120,
#  'langkah,NN': 7,
#  'menuju,VB': 4,
#  'lah,RP': 10,
#  'mulus,JJ': 2,
#  'orang,NND': 2,
#  'rekan,NN': 2,
#  'mengklaim,VB': 4,
#  'ide,NN': 1,
#  'pembuatan,NN': 4,
#  'datang,VB': 3,
#  'Mereka,PRP': 6,
#  'terlibat,VB': 1,
#  'sengketa,NN': 1,
#  'hukum,NN': 7,
#  'berlarut-larut,VB': 1,
#  '2008,CD': 43,
#  'diakhiri,VB': 1,
#  'pembayaran,NN': 10,
#  'dirahasiakan,VB': 1,
#  'jumlah,NN': 16,
#  'Cameron,NNP': 1,
#  'Tyler,NNP': 1,
#  'Winklevoss,NNP': 1,
#  'kini,NN': 5,
#  'bernama,VB': 3,
#  'ConnectU,NNP': 1,
#  'Perebutan,NN': 1,
#  'jamrud,NNP': 1,
#  'Bahia,NNP': 3,
#  'raksasa,JJ': 4,
#  'Jaksa,NN': 2,
#  'Kalifornia,NNP': 2,
#  'menanyai,VB': 1,
#  'menentukan,VB': 2,
#  'mengenai,SC': 1,
#  'kepemilikan,NN': 18,
#  'jamrud,NN': 4,
#  'disebut,VB': 4,
#  'terbesar,JJ': 11,
#  'Jamrud,NNP': 2,
#  'dinamakan,VB': 1,
#  'sesuai,JJ': 6,
#  'lokasi,NN': 1,
#  'penemuan,NN': 1,
#  'salah satu,CD': 7,
#  'daerah,NN': 12,
#  'Brasil,NNP': 6,
#  'berat,NN': 1,
#  '380,CD': 1,
#  'kg,NND': 2,
#  'Diperkirakan,VB': 1,
#  'bernilai,VB': 2,
#  '370,CD': 2,
#  'hak,NN': 3,
#  'atas,IN': 29,
#  'batu,NN': 5,
#  'mendengarkan,VB': 2,
#  'semua,CD': 10,
#  'permata,NN': 2,
#  'memutuskan,VB': 5,
#  'kasus,NN': 4,
#  'berselisih,VB': 1,
#  'Anthony,NNP': 1,
#  'Thomas,NNP': 3,
#  'ahli,NN': 1,
#  'konstruksi,NN': 7,
#  'membayar,VB': 5,
#  'agen,NN': 1,
#  'senilai,NN': 17,
#  '60,CD': 8,
#  'tak,NEG': 6,
#  'ditemukan,VB': 1,
#  'sembilan,CD': 6,
#  'lalu,NN': 1,
#  'mengatur,VB': 1,
#  'dikirim,VB': 2,
#  'melalui,IN': 21,
#  'kapal,NN': 6,
#  'ke,IN': 62,
#  'kediaman,NN': 1,
#  'San,NNP': 1,
#  'Jose,NNP': 1,
#  'tetapi,CC': 9,
#  'muncul,VB': 6,
#  'percaya,VB': 1,
#  'dicuri,VB': 1,
#  'dijual,VB': 3,
#  'kembali,RB': 26,
#  'harga,NN': 66,
#  'mahal,JJ': 2,
#  'hanya,RB': 23,
#  'pemilik,NN': 5,
#  'Satu,CD': 4,
#  'masalah,NN': 5,
#  'dihadapi,VB': 4,
#  'kehilangan,VB': 1,
#  'tanda terima,NN': 1,
#  'akibat,IN': 13,
#  'kebakaran,NN': 1,
#  'melanda,VB': 1,
#  'rumah,NN': 1,
#  'Jamrud,NN': 1,
#  'akhirnya,RB': 2,
#  'sampai,VB': 1,
#  'meskipun,SC': 4,
#  'setibanya,SC': 1,
#  'jelas,JJ': 3,
#  'siapa,SC': 3,
#  'hal,NN': 18,
#  'diketahui,VB': 1,
#  'sempat,MD': 7,
#  'disimpan,VB': 1,
#  'lemari besi,NN': 1,
#  'bank,NN': 25,
#  'New,NNP': 8,
#  'Orleans,NNP': 1,
#  'terkena,VB': 1,
#  'banjir,NN': 1,
#  'diterjang,VB': 1,
#  'Badai,NNP': 1,
#  'Katrina,NNP': 1,
#  'sehingga,SC': 30,
#  'berharga,JJ': 1,
#  'terendam,VB': 1,
#  'dalam,NN': 6,
#  'beberapa,CD': 20,
#  'bulan,NN': 44,
#  'kemudian,RB': 6,
#  'dibawa,VB': 1,
#  'Las,NNP': 1,
#  'Vegas,NNP': 1,
#  'dilihat,VB': 3,
#  'calon,NN': 3,
#  'pembeli,NN': 1,
#  'namun,CC': 21,
#  'disita,VB': 1,
#  'polisi,NN': 3,
#  'Los,NNP': 1,
#  'Angeles,NNP': 1,
#  'Badut,NN': 1,
#  'politikus,NN': 2,
#  'ditantang,VB': 2,
#  'baca,VB': 2,
#  'tulis,VB': 2,
#  'Seorang,NND': 4,
#  'badut,NN': 2,
#  'mempunyai,VB': 7,
#  'peluang,NN': 5,
#  'meraih,VB': 9,
#  'kursi,NN': 5,
#  'pemilihan,NN': 4,
#  'Minggu,NNP': 3,
#  '(,Z': 5,
#  '3,CD': 11,
#  '/,Z': 38,
#  '),Z': 5,
#  '-,Z': 104,
#  'membuktikan,VB': 3,
#  'membaca,VB': 5,
#  'menulis,VB': 1,
#  'Jajak,NN': 1,
#  'pendapat,NN': 1,
#  'memperlihatkan,VB': 7,
#  'Tiririca,NNP': 5,
#  'satu,CD': 11,
#  'suara,NN': 4,
#  'Namun,CC': 33,
#  'hakim,NN': 1,
#  'Sao,NNP': 1,
#  'Paulo,NNP': 1,
#  'menuntut,VB': 1,
#  'memenuhi,VB': 6,
#  'persyaratan,NN': 2,
#  'Sejumlah,CD': 1,
#  'surat kabar,NN': 1,
#  'sama,JJ': 38,
#  'seperti,IN': 19,
#  'sepuluh,CD': 5,
#  'buta aksara,JJ': 1,
#  'bahasa sehari-hari,NN': 1,
#  'Portugis,NNP': 1,
#  'tukang,NN': 1,
#  'mengeluh,VB': 1,
#  'sensasi,NN': 1,
#  'kampanye,NN': 2,
#  'Video,NN': 1,
#  'kocak,JJ': 1,
#  'jutaan,CD': 1,
#  'penonton,NN': 3,
#  'YouTube,NNP': 6,
#  'antara,IN': 22,
#  'menggunakan,VB': 11,
#  'slogan,NN': 1,
#  'Tidak,NEG': 1,
#  'buruk,JJ': 2,
#  'lagi,RB': 12,
#  'Apa,WH': 1,
#  'dilakukan,VB': 27,
#  'wakil,NN': 1,
#  'anda,PRP': 2,
#  '?,Z': 2,
#  'Sungguh,RB': 1,
#  'tahu,VB': 6,
#  'Tapi,CC': 4,
#  'pilih,VB': 1,
#  'mencari tahu,VB': 1,
#  'Hakim,NN': 1,
#  'menggelar,VB': 1,
#  'ujian,NN': 1,
#  'aksara,NN': 1,
#  'Epoca,NNP': 1,
#  'menayangkan,VB': 1,
#  'video,NN': 1,
#  'tampak,VB': 6,
#  'Komisi,NN': 1,
#  'terlambat,VB': 1,
#  'menghentikan,VB': 4,
#  'pencalonan,NN': 1,
#  'diberhentikan,VB': 1,
#  'jika,SC': 9,
#  'gagal,VB': 2,
#  'kemampuan,NN': 7,
#  'Calon,NN': 2,
#  'selebriti,NN': 3,
#  'nama,NN': 2,
#  'asli,JJ': 6,
#  'Francisco,NNP': 1,
#  'Everardo,NNP': 1,
#  'Oliveira,NNP': 1,
#  'Silva,NNP': 1,
#  'bekerja,VB': 5,
#  'sirkus,NN': 1,
#  'delapan,CD': 1,
#  'negara bagian,NN': 1,
#  'miskin,JJ': 1,
#  'Ceara,NNP': 1,
#  'Dengan,IN': 21,
#  'pengalaman,NN': 1,
#  'salah seorang,CD': 3,
#  'pelawak,NN': 1,
#  'terkenal,VB': 3,
#  'TV,NN': 5,
#  'merupakan,VB': 34,
#  'puluhan,CD': 1,
#  'berasal,VB': 10,
#  'olahraga,NN': 5,
#  'maupun,CC': 14,
#  'pertunjukan,NN': 1,
#  'berjuang,VB': 1,
#  'merebut,VB': 2,
#  'majelis rendah,NN': 1,
#  'bersaing,VB': 1,
#  'melawan,VB': 1,
#  'berpengalaman,VB': 1,
#  'Seluruhnya,RB': 1,
#  'tercatat,VB': 10,
#  '6,CD': 15,
#  '27,CD': 3,
#  'partai,NN': 1,
#  '513,CD': 1,
#  'diduga,VB': 2,
#  'kemenangan,NN': 2,
#  'mutlak,JJ': 1,
#  'Romario,NNP': 1,
#  'bintang,NN': 2,
#  'sepak bola,NN': 2,
#  'Piala,NNP': 3,
#  'Dunia,NNP': 17,
#  '1994,CD': 2,
#  'Para,DT': 3,
#  'pengamat,NN': 1,
#  'popularitas,NN': 1,
#  'mencerminkan,VB': 7,
#  'kebingungan,NN': 1,
#  'politik,NN': 1,
#  'utama,JJ': 9,
#  'karena,IN': 27,
#  'marak,JJ': 1,
#  'skandal,NN': 1,
#  'korupsi,NN': 4,
#  'Ibu,NN': 1,
#  'bayi,NN': 2,
#  'anggota,NN': 5,
#  'Parlemen,NNP': 2,
#  'Eropa,NNP': 4,
#  'asal,IN': 2,
#  'Italia,NNP': 2,
#  'sidang,NN': 4,
#  'Strasbourg,NNP': 1,
#  'menggendong,VB': 1,
#  'anak,NN': 6,
#  'Licia,NNP': 1,
#  'Ronzulli,NNP': 2,
#  'ia,PRP': 13,
#  'menunjukkan,VB': 19,
#  'berat,JJ': 5,
#  'beban,NN': 3,
#  'ditanggung,VB': 1,
#  'kaum,NN': 1,
#  'perempuan,NN': 2,
#  'menjalani,VB': 1,
#  'karir,NN': 1,
#  'sekaligus,RB': 4,
#  'mengasuh,VB': 1,
#  'sedang,MD': 8,
#  'membahas,VB': 3,
#  'usul,NN': 1,
#  'memperbaiki,VB': 9,
#  'kesempatan,NN': 6,
#  'Vittoria,NNP': 1,
#  'tidur,VB': 1,
#  'nyenyak,JJ': 1,
#  'selama,SC': 2,
#  'berlangsung,VB': 11,
#  'mewakili,VB': 2,
#  'Partai,NNP': 1,
#  'Kebebasan,NNP': 1,
#  'Rakyat,NNP': 1,
#  'pimpinan,NN': 2,
#  'PM,NNP': 5,
#  'Silvio,NNP': 1,
#  'Berlusconi,NNP': 1,
#  'mendapat,VB': 8,
#  'sambutan,NN': 1,
#  'meriah,JJ': 1,
#  'berdiri,VB': 1,
#  'menyampaikan,VB': 5,
#  'pidato,NN': 3,
#  'Ia,PRP': 25,
#  'sesama,NN': 1,
#  'melihat,VB': 9,
#  'komitmen,NN': 4,
#  'persoalan-persoalan,NN': 1,
#  'lembaga-lembaga,NN': 1,
#  'dimulai,VB': 2,
#  'Naskah,NN': 3,
#  'Harry,NNP': 3,
#  'Potter,NNP': 3,
#  'dipamerkan,VB': 4,
#  'tangan,NN': 1,
#  'pengarang,NN': 2,
#  'JK,NNP': 3,
#  'Rowling,NNP': 3,
#  'festival,NN': 3,
#  'buku,NN': 7,
#  'Skotlandia,NNP': 3,
#  'selatan,NNP': 1,
#  'halaman,NND': 1,
#  'naskah,NN': 3,
#  'dibingkai,VB': 1,
#  'ditandatangani,VB': 2,
#  'berisi,VB': 1,
#  'Balada,NN': 2,
#  'Nick,NNP': 3,
#  'Si,DT': 1,
#  'Kepala,NN': 8,
#  'Nyaris,RB': 2,
#  'Putus,VB': 2,
#  'Wigtown,NNP': 2,
#  '24,CD': 6,
#  'sampai,IN': 24,
#  'hantu,NN': 1,
#  'awal,NN': 19,
#  'Kamar,NN': 1,
#  'Rahasia,NN': 1,
#  'kemudian,CC': 6,
#  'kedua,CD': 8,
#  'halaman,NN': 5,
#  'dibuang,VB': 1,
#  'termasuk,VB': 20,
#  'diterbitkan,VB': 11,
#  'disumbangkan,VB': 2,
#  'Yayasan,NNP': 1,
#  'Kamus,NNP': 1,
#  'Bahasa,NNP': 2,
#  '2005,CD': 18,
#  'mendukung,VB': 10,
#  'pengumpulan,NN': 1,
#  'dana,NN': 26,
#  'kamus,NN': 1,
#  'baru,JJ': 15,
#  'bahasa,NN': 1,
#  'Sekarang,NN': 2,
#  'dimiliki,VB': 9,
#  'kolektor,NN': 1,
#  'terkemuka,JJ': 1,
#  'Inggris,NNP': 15,
#  'jurnal,NNP': 1,
#  'Asia,NNP': 12,
#  'Literary,NNP': 2,
#  'Review,NNP': 2,
#  'Ilyas,NNP': 2,
#  'Khan,NNP': 2,
#  'umum,NN': 1,
#  'senang,JJ': 1,
#  'ikut,VB': 2,
#  'Festival,NNP': 1,
#  'Memamerkan,VB': 1,
#  'si,DT': 3,
#  'cara,NN': 4,
#  'bagus,JJ': 4,
#  'Australia,NNP': 6,
#  'salah,JJ': 2,
#  'sebut,VB': 1,
#  'pemenang,NN': 6,
#  'Acara,NN': 1,
#  'Next,NNP': 1,
#  'Top,NNP': 1,
#  'Model,NNP': 1,
#  'mengumumkan,VB': 4,
#  'final,NN': 3,
#  'disiarkan,VB': 1,
#  'langsung,RB': 12,
#  'seri,NN': 9,
#  'keenam,OD': 3,
#  'Kelsey,NNP': 1,
#  'Martinovich,NNP': 2,
#  'dianugerahi,VB': 1,
#  'mahkota,NN': 1,
#  'pilihan,NN': 1,
#  'pemirsa,NN': 1,
#  'presenter,NNP': 1,
#  'Sarah,NNP': 4,
#  'Murdoch,NNP': 4,
#  'menyela,VB': 1,
#  'Sambil,SC': 1,
#  'menggeleng-gelengkan,VB': 1,
#  'kepala,NN': 1,
#  'ear,FW': 1,
#  'piece,FW': 1,
#  'mual,JJ': 1,
#  'amat,RB': 1,
#  'meminta,VB': 8,
#  'maaf,NN': 1,
#  'semata-mata,RB': 2,
#  'kecelakaan,NN': 1,
#  'yaitu,SC': 19,
#  'Amanda,NNP': 2,
#  'Ware,NNP': 2,
#  '18,CD': 8,
#  'Ini,PR': 10,
#  'terjadi,VB': 28,
#  'kalau,SC': 5,
#  'siaran,NN': 1,
#  'edan,JJ': 3,
#  'Adapun,CC': 1,
#  'sekitar,RB': 35,
#  'menit,NND': 1,
#  'menerima,VB': 5,
#  'kesalahan,NN': 1,
#  'baik,JJ': 28,
#  'Ok,FW': 1,
#  'kekeliruan,NN': 2,
#  'berusaha,VB': 3,
#  'menjelaskan,VB': 13,
#  'selisih,NN': 3,
#  'ketat,JJ': 4,
#  'Yang,DT': 3,
#  'memimpin,VB': 1,
#  'terus-menerus,RB': 2,
#  'berganti,VB': 1,
#  'Benar-benar,RB': 1,
#  'tergantung,VB': 3,
#  'Maju,VB': 1,
#  'mundur,VB': 1,
#  '-nya,PRP': 7,
#  'jelas,VB': 9,
#  'finalis,NN': 1,
#  'berpelukan,VB': 1,
#  'mengucapkan,VB': 1,
#  'terima kasih,NN': 1,
#  'pendukung,NN': 2,
#  'berjalan,VB': 10,
#  'atas,NN': 11,
#  'catwalk,FW': 1,
#  'terakhir,OD': 1,
#  'kali,NND': 6,
#  'Dan,CC': 2,
#  'model,NN': 2,
#  'merangkap,VB': 1,
#  'presenter,FW': 1,
#  'menikah,VB': 1,
#  'putra,NN': 1,
#  'Rupert,NNP': 1,
#  'Lachlan,NNP': 1,
#  'Membaca,VB': 1,
#  'Don,NNP': 3,
#  'Quixote,NNP': 3,
#  'Akademi,NNP': 2,
#  'Kerajaan,NNP': 4,
#  'Spanyol,NNP': 7,
#  'mengundang,VB': 1,
#  'merekam,VB': 1,
#  'segmen,NN': 8,
#  'novel,NN': 4,
#  'klasik,JJ': 2,
#  'mengunggah,VB': 1,
#  'Karya,NN': 1,
#  'Miguel,NNP': 1,
#  'de,NNP': 1,
#  'Cervantes,NNP': 1,
#  'paling,RB': 6,
#  'populer,JJ': 1,
#  'walau,SC': 1,
#  'pelindung,NN': 1,
#  'bahasa,NNP': 3,
#  'membagi,VB': 1,
#  'karya,NN': 3,
#  '2,CD': 7,
#  'Segmen-segmen,NN': 1,
#  'dibaca,VB': 1,
#  'direkam,VB': 1,
#  'sukarelawan,NN': 1,
#  'diunggah,VB': 2,
#  'Tujuan,NN': 1,
#  'mempromosikan,VB': 1,
#  'lengkap,JJ': 2,
#  'Ingenious,NNP': 1,
#  'Hidalgo,NNP': 1,
#  'of,NNP': 7,
#  'La,NNP': 1,
#  'Mancha,NNP': 2,
#  'ruang,NN': 2,
#  'sepatutnya,RB': 1,
#  'internet,NN': 1,
#  'sekretaris,NN': 1,
#  'akademi,NN': 1,
#  'Dario,NNP': 1,
#  'Villanueva,NNP': 1,
#  'Kami,PRP': 7,
#  'mengadukan,VB': 1,
#  'melakukan,VB': 30,
#  'sesuatu,PRP': 3,
#  'mengoreksi,VB': 1,
#  'Ditulis,VB': 1,
#  '1605,CD': 1,
#  'berkisah,VB': 1,
#  'petualangan,NN': 1,
#  'pria,NN': 3,
#  'pensiunan,NN': 1,
#  'kawasan,NN': 3,
#  'la,NNP': 1,
#  'punya,VB': 2,
#  'obsesi,NN': 1,
#  'gagasan-gagasan,NN': 1,
#  'kesatria,NN': 1,
#  'Novel,NN': 1,
#  'terdiri,VB': 18,
#  'bab,NN': 1,
#  'hampir,RB': 3,
#  '1,CD': 16,
#  'Bagi,IN': 1,
#  'berminat,VB': 1,
#  'mendaftarkan,VB': 1,
#  'terpilih,VB': 1,
#  'tertentu,JJ': 4,
#  'Hobbit,NNP': 3,
#  'cari,VB': 1,
#  'aktor,NN': 6,
#  'kerdil,JJ': 2,
#  'Tim,NN': 3,
#  'pembuat,NN': 2,
#  'mencari,VB': 5,
#  'Selandia,NNP': 2,
#  'Baru,NNP': 2,
#  'sementara,SC': 6,
#  'sutradara,NNP': 1,
#  'Peter,NNP': 2,
#  'Jackson,NNP': 3,
#  'berancang-ancang,VB': 1,
#  'merealisasikan,VB': 1,
#  'rencana,NN': 27,
#  'Sutradara,NNP': 1,
#  'Oscar,NNP': 2,
#  'Lord,NNP': 3,
#  'the,NNP': 4,
#  'Rings,NNP': 3,
#  ':,NNP': 2,
#  'Return,NNP': 2,
#  'King,NNP': 3,
#  'Iklan,NN': 1,
#  'koran,NN': 1,
#  'terbitan,NN': 1,
#  'Wellington,NNP': 2,
#  'Wingnut,NNP': 2,
#  'Films,NNP': 1,
#  'tinggi,NN': 5,
#  'badan,NN': 6,
#  '123,CD': 1,
#  'cm,NND': 5,
#  'maksimum,NN': 2,
#  '158,CD': 1,
#  'Proyek,NN': 1,
#  'lampu hijau,NN': 1,
#  'perusahaan,NN': 53,
#  'perfilman,NN': 1,
#  'MGM,NNP': 1,
#  'Studios,NNP': 1,
#  'kesulitan,NN': 2,
#  'keuangan,NN': 32,
#  'tengah,MD': 5,
#  'dialami,VB': 1,
#  'juru bicara,NNP': 1,
#  'bersiap-siap,VB': 1,
#  'Juru bicara,NN': 2,
#  'iklan,NN': 1,
#  'scale,FW': 1,
#  'double,FW': 3,
#  'mengisi,VB': 2,
#  'peran,NN': 2,
#  'dialog,NN': 3,
#  'sedangkan,CC': 21,
#  'audisi,NN': 1,
#  'diadakan,VB': 2,
#  'figuran,NN': 1,
#  'Scale,FW': 1,
#  'wide,FW': 1,
#  ...}

# %%
tag_trans
# Out:
# {'<start>,NN': 321,
#  'NN,SC': 437,
#  'SC,VB': 496,
#  'VB,NN': 938,
#  '<start>,NNP': 169,
#  'NNP,NNP': 1959,
#  'NNP,VB': 272,
#  'NN,JJ': 494,
#  'JJ,SC': 90,
#  'VB,RB': 65,
#  'RB,JJ': 137,
#  'JJ,IN': 154,
#  'IN,NN': 1280,
#  'NN,NNP': 509,
#  'NNP,Z': 743,
#  '<start>,CD': 26,
#  'CD,NN': 432,
#  'NN,VB': 296,
#  'RB,CD': 40,
#  'VB,IN': 479,
#  'NN,NN': 2103,
#  'NN,CC': 238,
#  'CC,NN': 334,
#  'NN,IN': 533,
#  'IN,NNP': 440,
#  'VB,CD': 253,
#  'CC,VB': 86,
#  'VB,VB': 140,
#  'CD,Z': 434,
#  'Z,NN': 386,
#  'NN,PR': 324,
#  'PR,VB': 140,
#  'JJ,Z': 204,
#  'VB,JJ': 80,
#  'Z,VB': 331,
#  'Z,CC': 127,
#  'JJ,CC': 66,
#  'VB,PRP': 174,
#  'PRP,MD': 45,
#  'MD,VB': 408,
#  'SC,NN': 206,
#  'JJ,JJ': 29,
#  'JJ,VB': 74,
#  'VB,Z': 189,
#  'CC,FW': 19,
#  'FW,VB': 22,
#  'SC,RB': 74,
#  'RB,VB': 171,
#  'NN,Z': 504,
#  'JJ,MD': 20,
#  'IN,CD': 239,
#  '<start>,Z': 26,
#  'PR,SC': 17,
#  'Z,Z': 54,
#  'VB,NNP': 158,
#  'NNP,IN': 261,
#  '<start>,IN': 182,
#  'CC,RB': 37,
#  '<start>,NEG': 1,
#  'NEG,JJ': 19,
#  'JJ,PR': 22,
#  'PR,NN': 31,
#  'PR,NEG': 15,
#  'NEG,MD': 22,
#  'VB,SC': 137,
#  'PRP,JJ': 11,
#  '<start>,CC': 88,
#  'CC,MD': 17,
#  'Z,NNP': 338,
#  'NNP,RB': 40,
#  'SC,JJ': 76,
#  'NN,MD': 96,
#  'NNP,CC': 106,
#  'CC,NNP': 86,
#  'NNP,MD': 61,
#  'PRP,VB': 141,
#  'NNP,SC': 105,
#  'PR,Z': 144,
#  'PRP,RB': 30,
#  'VB,DT': 6,
#  'DT,NN': 15,
#  'CD,VB': 164,
#  'JJ,NN': 107,
#  'PR,MD': 49,
#  'NN,PRP': 206,
#  'PRP,Z': 223,
#  '<start>,VB': 30,
#  'NN,NEG': 26,
#  'NEG,VB': 47,
#  'SC,MD': 79,
#  'Z,NND': 4,
#  'NND,NN': 60,
#  '<start>,PRP': 72,
#  'SC,PRP': 65,
#  'PRP,IN': 91,
#  'VB,CC': 29,
#  'VB,MD': 39,
#  'Z,SC': 141,
#  'Z,CD': 77,
#  'MD,MD': 26,
#  'CC,PRP': 10,
#  'RB,RB': 12,
#  'RB,MD': 29,
#  'NEG,RB': 16,
#  'NNP,JJ': 23,
#  '<start>,SC': 64,
#  'IN,SC': 9,
#  'IN,NND': 39,
#  'Z,MD': 19,
#  'SC,NNP': 41,
#  'NNP,CD': 159,
#  'Z,PR': 15,
#  'CC,Z': 38,
#  'Z,JJ': 21,
#  '<start>,NND': 5,
#  'Z,RB': 23,
#  'NN,CD': 330,
#  'CD,NNP': 75,
#  'NNP,NN': 74,
#  'NNP,PR': 20,
#  'PR,RB': 35,
#  'RB,NEG': 5,
#  'Z,PRP': 37,
#  'VB,NEG': 8,
#  'IN,PRP': 41,
#  'PRP,SC': 38,
#  'CD,RB': 15,
#  'RB,IN': 42,
#  'CD,CD': 721,
#  'CD,SC': 46,
#  '<start>,RB': 13,
#  'SC,SC': 16,
#  'PRP,PRP': 5,
#  'NNP,SYM': 5,
#  'SYM,CD': 278,
#  'NEG,RP': 4,
#  'RP,JJ': 2,
#  'CD,NND': 75,
#  'CD,CC': 101,
#  'NN,RB': 114,
#  'IN,JJ': 44,
#  'NND,Z': 26,
#  'CD,IN': 207,
#  'CC,NEG': 13,
#  'SC,IN': 27,
#  'NNP,NEG': 9,
#  'PRP,NN': 55,
#  'Z,NEG': 7,
#  'MD,RB': 46,
#  'JJ,RB': 21,
#  'RB,Z': 37,
#  'Z,WH': 2,
#  'WH,SC': 1,
#  'RB,PRP': 10,
#  'PRP,NEG': 12,
#  'VB,RP': 1,
#  'RP,PRP': 2,
#  'PRP,CC': 4,
#  'JJ,PRP': 59,
#  'PRP,NNP': 11,
#  '<start>,DT': 4,
#  'NN,DT': 2,
#  'PRP,CD': 20,
#  'PR,IN': 31,
#  'JJ,NNP': 40,
#  'NNP,DT': 2,
#  'CC,CC': 9,
#  'CC,CD': 53,
#  'SC,NEG': 20,
#  'SC,OD': 4,
#  'OD,Z': 17,
#  'VB,FW': 36,
#  'FW,FW': 157,
#  'FW,PRP': 4,
#  'RB,NN': 38,
#  'PR,RP': 4,
#  'RP,SC': 4,
#  'PR,JJ': 16,
#  'IN,RB': 15,
#  'NND,VB': 10,
#  'Z,FW': 30,
#  'FW,Z': 58,
#  'Z,DT': 2,
#  'DT,VB': 3,
#  'RB,NNP': 8,
#  'IN,DT': 3,
#  'NN,FW': 92,
#  'FW,IN': 36,
#  'IN,OD': 4,
#  'OD,NND': 4,
#  'FW,NN': 43,
#  'NEG,CD': 3,
#  'Z,IN': 113,
#  'VB,PR': 8,
#  'NN,NND': 3,
#  'CC,SC': 16,
#  'NND,CC': 8,
#  'CD,FW': 10,
#  'NND,IN': 15,
#  'NND,CD': 4,
#  'CC,IN': 38,
#  'CC,JJ': 35,
#  'IN,X': 3,
#  'X,CD': 2,
#  'PR,CC': 10,
#  'SC,RP': 1,
#  'MD,Z': 3,
#  'JJ,FW': 12,
#  'FW,CC': 16,
#  'RB,SC': 8,
#  'NEG,NN': 11,
#  'PRP,WH': 1,
#  'WH,PRP': 1,
#  'CD,SYM': 15,
#  'SYM,IN': 11,
#  'SYM,VB': 3,
#  'NN,RP': 3,
#  'CD,PRP': 5,
#  'PRP,PR': 4,
#  '<start>,PR': 17,
#  'SC,X': 2,
#  'X,JJ': 1,
#  'VB,SYM': 98,
#  'IN,FW': 27,
#  'NN,SYM': 59,
#  'NEG,Z': 3,
#  'FW,NNP': 26,
#  'JJ,CD': 114,
#  'NND,MD': 3,
#  'NN,OD': 79,
#  'CD,MD': 20,
#  'MD,CD': 2,
#  'IN,VB': 8,
#  'IN,PR': 38,
#  'JJ,OD': 3,
#  'OD,SC': 7,
#  '<start>,UH': 3,
#  'UH,PRP': 1,
#  'RB,PR': 3,
#  'PR,PRP': 6,
#  'FW,PR': 10,
#  'MD,JJ': 28,
#  'SC,PR': 26,
#  'PR,NNP': 6,
#  'MD,NN': 8,
#  'JJ,SYM': 53,
#  'CD,JJ': 34,
#  'RB,CC': 2,
#  'OD,IN': 10,
#  'OD,CC': 4,
#  'NND,NND': 14,
#  'IN,SYM': 34,
#  'CD,PR': 12,
#  'NND,RB': 1,
#  'OD,VB': 5,
#  'OD,CD': 31,
#  'NNP,FW': 18,
#  'SC,CD': 15,
#  'Z,SYM': 27,
#  'SYM,Z': 26,
#  'SYM,JJ': 5,
#  'IN,Z': 15,
#  'FW,SC': 16,
#  'OD,JJ': 2,
#  'CC,PR': 7,
#  'SC,FW': 4,
#  'FW,CD': 5,
#  'SC,Z': 3,
#  'PR,FW': 3,
#  'CC,SYM': 9,
#  'PRP,RP': 2,
#  'RP,MD': 1,
#  'FW,RB': 3,
#  'PRP,X': 2,
#  'X,VB': 2,
#  'VB,X': 2,
#  'X,UH': 1,
#  'UH,SC': 1,
#  'VB,NND': 4,
#  'RB,FW': 6,
#  'MD,PRP': 3,
#  'MD,IN': 7,
#  'IN,NEG': 1,
#  'IN,IN': 22,
#  'PRP,SYM': 8,
#  'OD,SYM': 1,
#  'NNP,OD': 3,
#  'RB,SYM': 13,
#  'OD,MD': 1,
#  'WH,NN': 1,
#  'CC,WH': 1,
#  'WH,VB': 2,
#  'SYM,SYM': 3,
#  '<start>,JJ': 4,
#  'NNP,PRP': 1,
#  'CD,NEG': 2,
#  'JJ,NEG': 2,
#  'RP,VB': 1,
#  'RP,NEG': 2,
#  'SYM,NN': 3,
#  'X,PRP': 1,
#  'FW,JJ': 15,
#  'NN,X': 4,
#  'X,NN': 1,
#  'X,Z': 4,
#  'FW,MD': 3,
#  'NNP,X': 1,
#  'FW,NEG': 2,
#  'VB,OD': 2,
#  'OD,NN': 14,
#  'NND,PRP': 3,
#  'RP,RB': 2,
#  '<start>,FW': 3,
#  'CC,OD': 1,
#  'NEG,IN': 2,
#  'JJ,RP': 1,
#  'RP,IN': 1,
#  'NND,SC': 4,
#  'UH,MD': 1,
#  'IN,MD': 1,
#  'OD,NNP': 1,
#  'NN,WH': 1,
#  'WH,RP': 2,
#  'RP,Z': 1,
#  'SC,WH': 1,
#  'WH,MD': 1,
#  'SC,CC': 1,
#  'RB,X': 1,
#  'DT,FW': 1,
#  'CD,OD': 1,
#  '<start>,WH': 1,
#  'FW,SYM': 5,
#  'PRP,FW': 1,
#  'SYM,CC': 1,
#  'PR,PR': 1,
#  'OD,PR': 1,
#  'JJ,WH': 1,
#  'RP,NN': 2,
#  'CC,DT': 1,
#  'DT,OD': 1,
#  '<start>,MD': 1,
#  'MD,CC': 1,
#  'NND,FW': 1,
#  'UH,NN': 1,
#  'X,IN': 1,
#  'SYM,FW': 1,
#  'X,NNP': 1,
#  'SC,SYM': 1,
#  'MD,NEG': 2,
#  'CC,NND': 1,
#  'X,SC': 1}

# %%
def create_trans_prob_table(tag_trans, tag_count):
#     print(tag_trans)
    trans_prob = {}
    for tag1 in tag_count.keys():
        for tag2 in tag_count.keys():
            #print('tag1 = ')
            #print(tag1)
            trans_idx = tag1+','+tag2
            #print('trans_idx = ')
            #print(trans_idx)
            if trans_idx in tag_trans:
                #print(trans_idx)
                trans_prob[trans_idx] = tag_trans[trans_idx]/tag_count[tag1]
    return trans_prob

# %%
trans_prob = create_trans_prob_table(tag_trans, tag_count)

# %%
trans_prob
# Out:
# {'<start>,NN': 0.3116504854368932,
#  '<start>,SC': 0.062135922330097085,
#  '<start>,VB': 0.02912621359223301,
#  '<start>,NNP': 0.16407766990291262,
#  '<start>,JJ': 0.003883495145631068,
#  '<start>,RB': 0.01262135922330097,
#  '<start>,IN': 0.1766990291262136,
#  '<start>,Z': 0.02524271844660194,
#  '<start>,CD': 0.02524271844660194,
#  '<start>,CC': 0.0854368932038835,
#  '<start>,PR': 0.01650485436893204,
#  '<start>,PRP': 0.06990291262135923,
#  '<start>,MD': 0.000970873786407767,
#  '<start>,FW': 0.002912621359223301,
#  '<start>,NEG': 0.000970873786407767,
#  '<start>,DT': 0.003883495145631068,
#  '<start>,NND': 0.0048543689320388345,
#  '<start>,WH': 0.000970873786407767,
#  '<start>,UH': 0.002912621359223301,
#  'NN,NN': 0.3253403465346535,
#  'NN,SC': 0.06760519801980198,
#  'NN,VB': 0.04579207920792079,
#  'NN,NNP': 0.07874381188118812,
#  'NN,JJ': 0.07642326732673267,
#  'NN,RB': 0.017636138613861384,
#  'NN,IN': 0.08245668316831684,
#  'NN,Z': 0.07797029702970297,
#  'NN,CD': 0.0510519801980198,
#  'NN,CC': 0.03681930693069307,
#  'NN,PR': 0.05012376237623763,
#  'NN,PRP': 0.03186881188118812,
#  'NN,MD': 0.01485148514851485,
#  'NN,FW': 0.014232673267326733,
#  'NN,NEG': 0.004022277227722772,
#  'NN,DT': 0.0003094059405940594,
#  'NN,NND': 0.0004641089108910891,
#  'NN,SYM': 0.009127475247524752,
#  'NN,RP': 0.0004641089108910891,
#  'NN,WH': 0.0001547029702970297,
#  'NN,OD': 0.012221534653465347,
#  'NN,X': 0.0006188118811881188,
#  'SC,NN': 0.17789291882556132,
#  'SC,SC': 0.013816925734024179,
#  'SC,VB': 0.4283246977547496,
#  'SC,NNP': 0.03540587219343696,
#  'SC,JJ': 0.06563039723661486,
#  'SC,RB': 0.06390328151986183,
#  'SC,IN': 0.023316062176165803,
#  'SC,Z': 0.0025906735751295338,
#  'SC,CD': 0.012953367875647668,
#  'SC,CC': 0.0008635578583765112,
#  'SC,PR': 0.022452504317789293,
#  'SC,PRP': 0.05613126079447323,
#  'SC,MD': 0.06822107081174439,
#  'SC,FW': 0.0034542314335060447,
#  'SC,NEG': 0.017271157167530225,
#  'SC,SYM': 0.0008635578583765112,
#  'SC,RP': 0.0008635578583765112,
#  'SC,WH': 0.0008635578583765112,
#  'SC,OD': 0.0034542314335060447,
#  'SC,X': 0.0017271157167530224,
#  'VB,NN': 0.3288920056100982,
#  'VB,SC': 0.048036465638148666,
#  'VB,VB': 0.04908835904628331,
#  'VB,NNP': 0.05539971949509116,
#  'VB,JJ': 0.028050490883590462,
#  'VB,RB': 0.02279102384291725,
#  'VB,IN': 0.16795231416549788,
#  'VB,Z': 0.06626928471248247,
#  'VB,CD': 0.08870967741935484,
#  'VB,CC': 0.010168302945301542,
#  'VB,PR': 0.002805049088359046,
#  'VB,PRP': 0.061009817671809255,
#  'VB,MD': 0.01367461430575035,
#  'VB,FW': 0.012622720897615708,
#  'VB,NEG': 0.002805049088359046,
#  'VB,DT': 0.0021037868162692847,
#  'VB,NND': 0.001402524544179523,
#  'VB,SYM': 0.034361851332398316,
#  'VB,RP': 0.0003506311360448808,
#  'VB,OD': 0.0007012622720897616,
#  'VB,X': 0.0007012622720897616,
#  'NNP,NN': 0.019131334022750777,
#  'NNP,SC': 0.027145811789038264,
#  'NNP,VB': 0.0703205791106515,
#  'NNP,NNP': 0.5064632885211996,
#  'NNP,JJ': 0.0059462254395036196,
#  'NNP,RB': 0.010341261633919338,
#  'NNP,IN': 0.06747673216132369,
#  'NNP,Z': 0.1920889348500517,
#  'NNP,CD': 0.04110651499482937,
#  'NNP,CC': 0.027404343329886244,
#  'NNP,PR': 0.005170630816959669,
#  'NNP,PRP': 0.0002585315408479835,
#  'NNP,MD': 0.01577042399172699,
#  'NNP,FW': 0.004653567735263702,
#  'NNP,NEG': 0.002326783867631851,
#  'NNP,DT': 0.000517063081695967,
#  'NNP,SYM': 0.0012926577042399173,
#  'NNP,OD': 0.0007755946225439503,
#  'NNP,X': 0.0002585315408479835,
#  'JJ,NN': 0.09944237918215613,
#  'JJ,SC': 0.08364312267657993,
#  'JJ,VB': 0.0687732342007435,
#  'JJ,NNP': 0.03717472118959108,
#  'JJ,JJ': 0.02695167286245353,
#  'JJ,RB': 0.019516728624535316,
#  'JJ,IN': 0.14312267657992564,
#  'JJ,Z': 0.1895910780669145,
#  'JJ,CD': 0.10594795539033457,
#  'JJ,CC': 0.06133828996282528,
#  'JJ,PR': 0.020446096654275093,
#  'JJ,PRP': 0.05483271375464684,
#  'JJ,MD': 0.01858736059479554,
#  'JJ,FW': 0.011152416356877323,
#  'JJ,NEG': 0.0018587360594795538,
#  'JJ,SYM': 0.04925650557620818,
#  'JJ,RP': 0.0009293680297397769,
#  'JJ,WH': 0.0009293680297397769,
#  'JJ,OD': 0.0027881040892193307,
#  'RB,NN': 0.06761565836298933,
#  'RB,SC': 0.014234875444839857,
#  'RB,VB': 0.304270462633452,
#  'RB,NNP': 0.014234875444839857,
#  'RB,JJ': 0.24377224199288255,
#  'RB,RB': 0.021352313167259787,
#  'RB,IN': 0.07473309608540925,
#  'RB,Z': 0.06583629893238434,
#  'RB,CD': 0.0711743772241993,
#  'RB,CC': 0.0035587188612099642,
#  'RB,PR': 0.005338078291814947,
#  'RB,PRP': 0.017793594306049824,
#  'RB,MD': 0.051601423487544484,
#  'RB,FW': 0.010676156583629894,
#  'RB,NEG': 0.008896797153024912,
#  'RB,SYM': 0.023131672597864767,
#  'RB,X': 0.0017793594306049821,
#  'IN,NN': 0.5656208572691118,
#  'IN,SC': 0.003977021652673442,
#  'IN,VB': 0.003535130357931949,
#  'IN,NNP': 0.19443216968625718,
#  'IN,JJ': 0.019443216968625717,
#  'IN,RB': 0.006628369421122404,
#  'IN,IN': 0.009721608484312859,
#  'IN,Z': 0.006628369421122404,
#  'IN,CD': 0.10561201944321696,
#  'IN,PR': 0.016791869200176758,
#  'IN,PRP': 0.018117543084401236,
#  'IN,MD': 0.0004418912947414936,
#  'IN,FW': 0.011931064958020326,
#  'IN,NEG': 0.0004418912947414936,
#  'IN,DT': 0.0013256738842244808,
#  'IN,NND': 0.01723376049491825,
#  'IN,SYM': 0.015024304021210782,
#  'IN,OD': 0.0017675651789659744,
#  'IN,X': 0.0013256738842244808,
#  'Z,NN': 0.14026162790697674,
#  'Z,SC': 0.05123546511627907,
#  'Z,VB': 0.12027616279069768,
#  'Z,NNP': 0.12281976744186046,
#  'Z,JJ': 0.007630813953488372,
#  'Z,RB': 0.008357558139534883,
#  'Z,IN': 0.041061046511627904,
#  'Z,Z': 0.019622093023255814,
#  'Z,CD': 0.0279796511627907,
#  'Z,CC': 0.04614825581395349,
#  'Z,PR': 0.005450581395348837,
#  'Z,PRP': 0.013444767441860465,
#  'Z,MD': 0.006904069767441861,
#  'Z,FW': 0.010901162790697675,
#  'Z,NEG': 0.002543604651162791,
#  'Z,DT': 0.0007267441860465116,
#  'Z,NND': 0.0014534883720930232,
#  'Z,SYM': 0.009811046511627907,
#  'Z,WH': 0.0007267441860465116,
#  'CD,NN': 0.1821247892074199,
#  'CD,SC': 0.0193929173693086,
#  'CD,VB': 0.06913996627318718,
#  'CD,NNP': 0.031618887015177066,
#  'CD,JJ': 0.01433389544688027,
#  'CD,RB': 0.006323777403035413,
#  'CD,IN': 0.0872681281618887,
#  'CD,Z': 0.18296795952782463,
#  'CD,CD': 0.3039629005059022,
#  'CD,CC': 0.04258010118043845,
#  'CD,PR': 0.00505902192242833,
#  'CD,PRP': 0.0021079258010118043,
#  'CD,MD': 0.008431703204047217,
#  'CD,FW': 0.0042158516020236085,
#  'CD,NEG': 0.0008431703204047217,
#  'CD,NND': 0.031618887015177066,
#  'CD,SYM': 0.006323777403035413,
#  'CD,OD': 0.00042158516020236085,
#  'CC,NN': 0.4118372379778052,
#  'CC,SC': 0.01972872996300863,
#  'CC,VB': 0.1060419235511714,
#  'CC,NNP': 0.1060419235511714,
#  'CC,JJ': 0.04315659679408138,
#  'CC,RB': 0.04562268803945746,
#  'CC,IN': 0.0468557336621455,
#  'CC,Z': 0.0468557336621455,
#  'CC,CD': 0.06535141800246609,
#  'CC,CC': 0.011097410604192354,
#  'CC,PR': 0.008631319358816275,
#  'CC,PRP': 0.012330456226880395,
#  'CC,MD': 0.02096177558569667,
#  'CC,FW': 0.02342786683107275,
#  'CC,NEG': 0.016029593094944512,
#  'CC,DT': 0.0012330456226880395,
#  'CC,NND': 0.0012330456226880395,
#  'CC,SYM': 0.011097410604192354,
#  'CC,WH': 0.0012330456226880395,
#  'CC,OD': 0.0012330456226880395,
#  'PR,NN': 0.0610236220472441,
#  'PR,SC': 0.03346456692913386,
#  'PR,VB': 0.2755905511811024,
#  'PR,NNP': 0.011811023622047244,
#  'PR,JJ': 0.031496062992125984,
#  'PR,RB': 0.0688976377952756,
#  'PR,IN': 0.0610236220472441,
#  'PR,Z': 0.28346456692913385,
#  'PR,CC': 0.01968503937007874,
#  'PR,PR': 0.001968503937007874,
#  'PR,PRP': 0.011811023622047244,
#  'PR,MD': 0.09645669291338582,
#  'PR,FW': 0.005905511811023622,
#  'PR,NEG': 0.02952755905511811,
#  'PR,RP': 0.007874015748031496,
#  'PRP,NN': 0.07790368271954674,
#  'PRP,SC': 0.053824362606232294,
#  'PRP,VB': 0.19971671388101983,
#  'PRP,NNP': 0.015580736543909348,
#  'PRP,JJ': 0.015580736543909348,
#  'PRP,RB': 0.042492917847025496,
#  'PRP,IN': 0.12889518413597734,
#  'PRP,Z': 0.31586402266288954,
#  'PRP,CD': 0.028328611898016998,
#  'PRP,CC': 0.0056657223796034,
#  'PRP,PR': 0.0056657223796034,
#  'PRP,PRP': 0.007082152974504249,
#  'PRP,MD': 0.06373937677053824,
#  'PRP,FW': 0.00141643059490085,
#  'PRP,NEG': 0.0169971671388102,
#  'PRP,SYM': 0.0113314447592068,
#  'PRP,RP': 0.0028328611898017,
#  'PRP,WH': 0.00141643059490085,
#  'PRP,X': 0.0028328611898017,
#  'MD,NN': 0.0149812734082397,
#  'MD,VB': 0.7640449438202247,
#  'MD,JJ': 0.052434456928838954,
#  'MD,RB': 0.08614232209737828,
#  'MD,IN': 0.013108614232209739,
#  'MD,Z': 0.0056179775280898875,
#  'MD,CD': 0.003745318352059925,
#  'MD,CC': 0.0018726591760299626,
#  'MD,PRP': 0.0056179775280898875,
#  'MD,MD': 0.04868913857677903,
#  'MD,NEG': 0.003745318352059925,
#  'FW,NN': 0.1021377672209026,
#  'FW,SC': 0.03800475059382423,
#  'FW,VB': 0.052256532066508314,
#  'FW,NNP': 0.06175771971496437,
#  'FW,JJ': 0.035629453681710214,
#  'FW,RB': 0.007125890736342043,
#  'FW,IN': 0.0855106888361045,
#  'FW,Z': 0.1377672209026128,
#  'FW,CD': 0.011876484560570071,
#  'FW,CC': 0.03800475059382423,
#  'FW,PR': 0.023752969121140142,
#  'FW,PRP': 0.009501187648456057,
#  'FW,MD': 0.007125890736342043,
#  'FW,FW': 0.37292161520190026,
#  'FW,NEG': 0.004750593824228029,
#  'FW,SYM': 0.011876484560570071,
#  'NEG,NN': 0.08661417322834646,
#  'NEG,VB': 0.3700787401574803,
#  'NEG,JJ': 0.14960629921259844,
#  'NEG,RB': 0.12598425196850394,
#  'NEG,IN': 0.015748031496062992,
#  'NEG,Z': 0.023622047244094488,
#  'NEG,CD': 0.023622047244094488,
#  'NEG,MD': 0.1732283464566929,
#  'NEG,RP': 0.031496062992125984,
#  'DT,NN': 0.75,
#  'DT,VB': 0.15,
#  'DT,FW': 0.05,
#  'DT,OD': 0.05,
#  'NND,NN': 0.40268456375838924,
#  'NND,SC': 0.026845637583892617,
#  'NND,VB': 0.06711409395973154,
#  'NND,RB': 0.006711409395973154,
#  'NND,IN': 0.10067114093959731,
#  'NND,Z': 0.174496644295302,
#  'NND,CD': 0.026845637583892617,
#  'NND,CC': 0.053691275167785234,
#  'NND,PRP': 0.020134228187919462,
#  'NND,MD': 0.020134228187919462,
#  'NND,FW': 0.006711409395973154,
#  'NND,NND': 0.09395973154362416,
#  'SYM,NN': 0.00906344410876133,
#  'SYM,VB': 0.00906344410876133,
#  'SYM,JJ': 0.015105740181268883,
#  'SYM,IN': 0.03323262839879154,
#  'SYM,Z': 0.07854984894259819,
#  'SYM,CD': 0.8398791540785498,
#  'SYM,CC': 0.0030211480362537764,
#  'SYM,FW': 0.0030211480362537764,
#  'SYM,SYM': 0.00906344410876133,
#  'RP,NN': 0.1111111111111111,
#  'RP,SC': 0.2222222222222222,
#  'RP,VB': 0.05555555555555555,
#  'RP,JJ': 0.1111111111111111,
#  'RP,RB': 0.1111111111111111,
#  'RP,IN': 0.05555555555555555,
#  'RP,Z': 0.05555555555555555,
#  'RP,PRP': 0.1111111111111111,
#  'RP,MD': 0.05555555555555555,
#  'RP,NEG': 0.1111111111111111,
#  'WH,NN': 0.125,
#  'WH,SC': 0.125,
#  'WH,VB': 0.25,
#  'WH,PRP': 0.125,
#  'WH,MD': 0.125,
#  'WH,RP': 0.25,
#  'OD,NN': 0.14285714285714285,
#  'OD,SC': 0.07142857142857142,
#  'OD,VB': 0.05102040816326531,
#  'OD,NNP': 0.01020408163265306,
#  'OD,JJ': 0.02040816326530612,
#  'OD,IN': 0.10204081632653061,
#  'OD,Z': 0.17346938775510204,
#  'OD,CD': 0.3163265306122449,
#  'OD,CC': 0.04081632653061224,
#  'OD,PR': 0.01020408163265306,
#  'OD,MD': 0.01020408163265306,
#  'OD,NND': 0.04081632653061224,
#  'OD,SYM': 0.01020408163265306,
#  'X,NN': 0.06666666666666667,
#  'X,SC': 0.06666666666666667,
#  'X,VB': 0.13333333333333333,
#  'X,NNP': 0.06666666666666667,
#  'X,JJ': 0.06666666666666667,
#  'X,IN': 0.06666666666666667,
#  'X,Z': 0.26666666666666666,
#  'X,CD': 0.13333333333333333,
#  'X,PRP': 0.06666666666666667,
#  'X,UH': 0.06666666666666667,
#  'UH,NN': 0.25,
#  'UH,SC': 0.25,
#  'UH,PRP': 0.25,
#  'UH,MD': 0.25}

# %%
def create_emission_prob_table(word_tag, tag_count):
    emission_prob = {}
    for word_tag_entry in word_tag.keys():
        word_tag_split = word_tag_entry.split(',')
        current_word = word_tag_split[0]
        current_tag = word_tag_split[1]
        emission_key = current_word+","+current_tag
        if len(word_tag_split)==2:
            emission_prob[emission_key] = word_tag[word_tag_entry]/tag_count[current_tag]    
    return emission_prob

# %%
emission_prob = create_emission_prob_table(word_tag, tag_count)

# %%
emission_prob
# Out:
# {'Kera,NN': 0.0001547029702970297,
#  'untuk,SC': 0.10880829015544041,
#  'amankan,VB': 0.0003506311360448808,
#  'pesta olahraga,NN': 0.0001547029702970297,
#  'Pemerintah,NNP': 0.000517063081695967,
#  'kota,NNP': 0.0007755946225439503,
#  'Delhi,NNP': 0.0012926577042399173,
#  'mengerahkan,VB': 0.0003506311360448808,
#  'monyet,NN': 0.0018564356435643563,
#  'mengusir,VB': 0.001402524544179523,
#  'monyet-monyet,NN': 0.0003094059405940594,
#  'lain,JJ': 0.02695167286245353,
#  'yang,SC': 0.46459412780656306,
#  'berbadan,VB': 0.0007012622720897616,
#  'lebih,RB': 0.1423487544483986,
#  'kecil,JJ': 0.013011152416356878,
#  'dari,IN': 0.11091471498011489,
#  'arena,NN': 0.0003094059405940594,
#  'Pesta Olahraga,NNP': 0.0002585315408479835,
#  'Persemakmuran,NNP': 0.0002585315408479835,
#  '.,Z': 0.36773255813953487,
#  'Beberapa,CD': 0.00042158516020236085,
#  'laporan,NN': 0.0023205445544554454,
#  'menyebutkan,VB': 0.0035063113604488078,
#  'setidaknya,RB': 0.0035587188612099642,
#  '10,CD': 0.00885328836424958,
#  'ditempatkan,VB': 0.0007012622720897616,
#  'di,IN': 0.1590808661069377,
#  'luar,NN': 0.0007735148514851486,
#  'lomba,NN': 0.0001547029702970297,
#  'dan,CC': 0.593094944512947,
#  'pertandingan,NN': 0.0001547029702970297,
#  'ibukota,NNP': 0.000517063081695967,
#  'India,NNP': 0.0015511892450879006,
#  'Pemkot,NNP': 0.0002585315408479835,
#  'memiliki,VB': 0.0070126227208976155,
#  '28,CD': 0.002529510961214165,
#  'berencana,VB': 0.003155680224403927,
#  'mendatangkan,VB': 0.0007012622720897616,
#  'sejenis,NN': 0.0001547029702970297,
#  'negara bagian,NNP': 0.0002585315408479835,
#  'Rajasthan,NNP': 0.0002585315408479835,
#  'Jumlah,NN': 0.0007735148514851486,
#  'mencapai,VB': 0.034011220196353435,
#  'ribuan,CD': 0.00042158516020236085,
#  'sebagian besar,NN': 0.0004641089108910891,
#  'berada,VB': 0.004908835904628331,
#  'kantor-kantor,NN': 0.0001547029702970297,
#  'pemerintah,NN': 0.008044554455445545,
#  'hewan,NN': 0.0001547029702970297,
#  'ini,PR': 0.39173228346456695,
#  'dianggap,VB': 0.001402524544179523,
#  'mengganggu,VB': 0.0010518934081346423,
#  'ketertiban,NN': 0.0001547029702970297,
#  'umum,JJ': 0.008364312267657992,
#  'Jenis,NN': 0.0001547029702970297,
#  'dikerahkan,VB': 0.0010518934081346423,
#  'pemkot,NN': 0.0001547029702970297,
#  'besar,JJ': 0.03066914498141264,
#  'berekor,VB': 0.0003506311360448808,
#  'panjang,JJ': 0.0037174721189591076,
#  'wajah,NN': 0.0001547029702970297,
#  'berwarna,VB': 0.0003506311360448808,
#  'hitam,JJ': 0.0009293680297397769,
#  'Monyet,NN': 0.0004641089108910891,
#  'diikat,VB': 0.0003506311360448808,
#  'dengan,IN': 0.07777286787450287,
#  'tali,NN': 0.0003094059405940594,
#  'pelatih,NN': 0.0001547029702970297,
#  'mengawasi,VB': 0.0007012622720897616,
#  'mereka,PRP': 0.032577903682719546,
#  'akan,MD': 0.3595505617977528,
#  'melepas,VB': 0.001402524544179523,
#  'begitu,SC': 0.0008635578583765112,
#  'mendekat,VB': 0.0003506311360448808,
#  'Kantor,NNP': 0.0015511892450879006,
#  'berita,NNP': 0.0002585315408479835,
#  'AFP,NNP': 0.001034126163391934,
#  'melaporkan,VB': 0.001402524544179523,
#  'stadion,NN': 0.0004641089108910891,
#  'tinju,NN': 0.0001547029702970297,
#  'hockey,FW': 0.0023752969121140144,
#  'mendapatkan,VB': 0.0010518934081346423,
#  'perhatian,NN': 0.0003094059405940594,
#  'khusus,JJ': 0.012081784386617101,
#  'karena,SC': 0.03540587219343696,
#  'sering,RB': 0.005338078291814947,
#  'diserbu,VB': 0.0003506311360448808,
#  'dua,CD': 0.00885328836424958,
#  'serbuan,NN': 0.0003094059405940594,
#  '",Z': 0.025436046511627907,
#  'tersebut,PR': 0.23228346456692914,
#  'kata,VB': 0.05750350631136045,
#  'Devender,NNP': 0.0002585315408479835,
#  'Prasad,NNP': 0.0002585315408479835,
#  'pejabat,NN': 0.0004641089108910891,
#  'pemerintah,NNP': 0.0015511892450879006,
#  'kepada,IN': 0.024745912505523642,
#  'kantor berita,NNP': 0.0007755946225439503,
#  'Selama,IN': 0.0013256738842244808,
#  'bertahun-tahun,CD': 0.00042158516020236085,
#  'warga,NN': 0.0003094059405940594,
#  'Binatang,NN': 0.0003094059405940594,
#  'menaiki,VB': 0.0003506311360448808,
#  'kereta,NN': 0.0001547029702970297,
#  'metro,NN': 0.0001547029702970297,
#  'bahkan,RB': 0.014234875444839857,
#  'berkeliaran,VB': 0.0003506311360448808,
#  'kompleks,NN': 0.0001547029702970297,
#  'gedung,NN': 0.0001547029702970297,
#  'parlemen,NN': 0.0017017326732673267,
#  'Belum,NEG': 0.007874015748031496,
#  'lama,JJ': 0.0018587360594795538,
#  'kawanan,NN': 0.0004641089108910891,
#  'menyerbu,VB': 0.0003506311360448808,
#  'kantor,NN': 0.0003094059405940594,
#  'perdana menteri,NN': 0.0004641089108910891,
#  'departemen,NN': 0.0004641089108910891,
#  'pertahanan,NN': 0.0001547029702970297,
#  'tidak,NEG': 0.6377952755905512,
#  'bisa,MD': 0.07865168539325842,
#  'dibunuh,VB': 0.0003506311360448808,
#  'masyarakat,NN': 0.0018564356435643563,
#  'menganggap,VB': 0.0007012622720897616,
#  'suci,JJ': 0.0009293680297397769,
#  'Selain,CC': 0.0012330456226880395,
#  'harus,MD': 0.028089887640449437,
#  'pemkot,NNP': 0.0002585315408479835,
#  'juga,RB': 0.13345195729537365,
#  'kesulitan,VB': 0.0010518934081346423,
#  'mengatasi,VB': 0.0017531556802244039,
#  'wabah,NN': 0.0001547029702970297,
#  'demam berdarah,NN': 0.0001547029702970297,
#  'Curah,NN': 0.0001547029702970297,
#  'hujan,NN': 0.0001547029702970297,
#  'tinggi,JJ': 0.03066914498141264,
#  'menyebabkan,VB': 0.0017531556802244039,
#  'banyak,CD': 0.00927487352445194,
#  'genangan,NN': 0.0003094059405940594,
#  'tempat,NN': 0.0007735148514851486,
#  'ideal,JJ': 0.0018587360594795538,
#  'bagi,IN': 0.009721608484312859,
#  'nyamuk,NN': 0.0003094059405940594,
#  'aedes,NNP': 0.0002585315408479835,
#  'berkembang biak,VB': 0.0003506311360448808,
#  'Pemkot,NN': 0.0001547029702970297,
#  'telah,MD': 0.1348314606741573,
#  'menempatkan,VB': 0.0007012622720897616,
#  'ikan,NN': 0.0001547029702970297,
#  'berbagai,CD': 0.0042158516020236085,
#  'air,NN': 0.0007735148514851486,
#  'memangsa,VB': 0.0003506311360448808,
#  'telur,NN': 0.0001547029702970297,
#  'Miliarder,NN': 0.0001547029702970297,
#  'AS,NNP': 0.039555325749741466,
#  'jamu,VB': 0.0003506311360448808,
#  'orang kaya,NN': 0.0001547029702970297,
#  'Cina,NNP': 0.0015511892450879006,
#  'Dua,CD': 0.0012647554806070826,
#  'miliarder,NN': 0.0003094059405940594,
#  'Amerika,NNP': 0.003360910031023785,
#  'Bill,NNP': 0.0002585315408479835,
#  'Gates,NNP': 0.000517063081695967,
#  'Warren,NNP': 0.0002585315408479835,
#  'Buffett,NNP': 0.000517063081695967,
#  'mengadakan,VB': 0.0010518934081346423,
#  'jamuan,NN': 0.0004641089108910891,
#  'makan malam,NN': 0.0004641089108910891,
#  'Beijing,NNP': 0.0002585315408479835,
#  'sejumlah,CD': 0.002529510961214165,
#  'orang,NN': 0.0024752475247524753,
#  'terkaya,JJ': 0.0027881040892193307,
#  'mengatakan,VB': 0.03225806451612903,
#  'mempelajari,VB': 0.0003506311360448808,
#  'kegiatan,NN': 0.0007735148514851486,
#  'amal,NN': 0.0007735148514851486,
#  'negara,NN': 0.007735148514851485,
#  'itu,PR': 0.2874015748031496,
#  'Banyak,CD': 0.0012647554806070826,
#  'menduga,VB': 0.0003506311360448808,
#  'ingin,RB': 0.012455516014234875,
#  'membujuk,VB': 0.0007012622720897616,
#  'para,DT': 0.45,
#  'tamu,NN': 0.0003094059405940594,
#  'agar,SC': 0.007772020725388601,
#  'menyumbang,VB': 0.001402524544179523,
#  'untuk,IN': 0.04507291206363235,
#  'Kedua,CD': 0.0012647554806070826,
#  'dunia,NN': 0.0032487623762376236,
#  'sudah,MD': 0.0599250936329588,
#  'berhasil,VB': 0.0038569424964936885,
#  'sangat,RB': 0.04448398576512456,
#  'kaya,JJ': 0.0018587360594795538,
#  'menyumbangkan,VB': 0.0007012622720897616,
#  'separuh,CD': 0.00042158516020236085,
#  'kekayaan,NN': 0.0004641089108910891,
#  'Ada,VB': 0.0003506311360448808,
#  'kerahasiaan,NN': 0.0001547029702970297,
#  'mengenai,IN': 0.003535130357931949,
#  'acara,NN': 0.0009282178217821782,
#  'pihak,NN': 0.0038675742574257425,
#  'penyelenggara,NN': 0.0001547029702970297,
#  'membeberkan,VB': 0.0003506311360448808,
#  'nama-nama,NN': 0.0003094059405940594,
#  'Salah satu,CD': 0.0016863406408094434,
#  'menghadiri,VB': 0.0007012622720897616,
#  'adalah,VB': 0.012622720897615708,
#  'Chen,NNP': 0.0002585315408479835,
#  'Guangbiao,NNP': 0.0002585315408479835,
#  'seorang,NND': 0.040268456375838924,
#  'meraup,VB': 0.0003506311360448808,
#  'bisnis,NN': 0.002165841584158416,
#  'mendaur ulang,VB': 0.0003506311360448808,
#  'sampah,NN': 0.0001547029702970297,
#  'industri,NN': 0.004331683168316832,
#  'bangunan,NN': 0.0001547029702970297,
#  'Dia,PRP': 0.029745042492917848,
#  'BBC,NNP': 0.0002585315408479835,
#  'bahwa,SC': 0.03281519861830743,
#  'dia,PRP': 0.07932011331444759,
#  'seluruh,CD': 0.006745362563237774,
#  'harta,NN': 0.0001547029702970297,
#  '#NAME?,PRP': 0.6359773371104815,
#  'bila,SC': 0.0034542314335060447,
#  'meninggal,VB': 0.0007012622720897616,
#  'Beramal,VB': 0.0003506311360448808,
#  'membantu,VB': 0.0035063113604488078,
#  'menjadi,VB': 0.04453015427769986,
#  'bagian,NN': 0.0012376237623762376,
#  'budaya,NN': 0.0001547029702970297,
#  'selama,IN': 0.009279717189571365,
#  '5.000,CD': 0.00042158516020236085,
#  'tahun,NN': 0.02599009900990099,
#  'Tetapi,CC': 0.002466091245376079,
#  'resmi,JJ': 0.008364312267657992,
#  'baru,MD': 0.020599250936329586,
#  'dikembangkan,VB': 0.0007012622720897616,
#  'dalam,IN': 0.07688908528501988,
#  '30,CD': 0.00885328836424958,
#  'terakhir,JJ': 0.012081784386617101,
#  'sejak,SC': 0.0025906735751295338,
#  'kami,PRP': 0.018413597733711047,
#  'menerapkan,VB': 0.0003506311360448808,
#  'reformasi ekonomi,NN': 0.0001547029702970297,
#  'mulai,MD': 0.028089887640449437,
#  'baru-baru ini,RB': 0.005338078291814947,
#  'saja,RB': 0.021352313167259787,
#  'memberi,VB': 0.001402524544179523,
#  'makan,NN': 0.0001547029702970297,
#  'diri,NN': 0.0004641089108910891,
#  'sendiri,NN': 0.0013923267326732673,
#  'Menyumbangkan,VB': 0.0003506311360448808,
#  'uang,NN': 0.0004641089108910891,
#  'belum,NEG': 0.2125984251968504,
#  'begitu,RB': 0.0017793594306049821,
#  'berkembang,VB': 0.001402524544179523,
#  'sebaik,JJ': 0.0018587360594795538,
#  'Kalau,SC': 0.004317789291882556,
#  'dikatakan,VB': 0.0007012622720897616,
#  'keberhasilan,NN': 0.0003094059405940594,
#  'mendorong,VB': 0.004207573632538569,
#  'perdebatan,NN': 0.0001547029702970297,
#  'apa,SC': 0.0017271157167530224,
#  'arti,NN': 0.0004641089108910891,
#  'beramal,VB': 0.0003506311360448808,
#  'membutuhkan,VB': 0.0017531556802244039,
#  'Kisah,NN': 0.0004641089108910891,
#  'pendiri,NN': 0.0003094059405940594,
#  'Facebook,NNP': 0.0012926577042399173,
#  'dibuat,VB': 0.0007012622720897616,
#  'komik,NN': 0.0003094059405940594,
#  'Mark,NNP': 0.0007755946225439503,
#  'Zuckerberg,NNP': 0.0015511892450879006,
#  'diceritakan,VB': 0.0003506311360448808,
#  'sebuah,NND': 0.12080536912751678,
#  'biografi,NN': 0.0001547029702970297,
#  'Komik,NN': 0.0001547029702970297,
#  'judul,NN': 0.0004641089108910891,
#  ':,Z': 0.001816860465116279,
#  'Pencipta,NN': 0.0001547029702970297,
#  'tersedia,VB': 0.0003506311360448808,
#  'pasar,NN': 0.004641089108910891,
#  'sebelum,SC': 0.03626943005181347,
#  'Desember,NNP': 0.0036194415718717684,
#  '2010,CD': 0.0016863406408094434,
#  'demikian,PR': 0.03937007874015748,
#  'pernyataan,NN': 0.0013923267326732673,
#  'penerbit,NNP': 0.0002585315408479835,
#  'Bluewater,NNP': 0.0002585315408479835,
#  'Productions,NNP': 0.0002585315408479835,
#  'Penulis,NNP': 0.0002585315408479835,
#  'Jerome,NNP': 0.0002585315408479835,
#  'Maida,NNP': 0.0002585315408479835,
#  'menyebut,VB': 0.0003506311360448808,
#  'kisah,NN': 0.0003094059405940594,
#  'mengagumkan,VB': 0.0003506311360448808,
#  'luar biasa,JJ': 0.0018587360594795538,
#  'Sebuah,NND': 0.006711409395973154,
#  'film,NN': 0.001082920792079208,
#  'The,NNP': 0.005170630816959669,
#  'Social,NNP': 0.0002585315408479835,
#  'Network,NNP': 0.0002585315408479835,
#  'dirilis,VB': 0.0003506311360448808,
#  'pada,IN': 0.12019443216968625,
#  'tanggal,NN': 0.0017017326732673267,
#  '15,CD': 0.007588532883642495,
#  'Oktober,NNP': 0.00749741468459152,
#  'nanti,NN': 0.0007735148514851486,
#  'Film,NN': 0.0001547029702970297,
#  'ditulis,VB': 0.001402524544179523,
#  'oleh,IN': 0.03844454264250994,
#  'pencipta,NN': 0.0001547029702970297,
#  'serial,NN': 0.0001547029702970297,
#  'West,NNP': 0.0002585315408479835,
#  'Wing,NNP': 0.0002585315408479835,
#  'Aaron,NNP': 0.0002585315408479835,
#  'Sorkin,NNP': 0.0002585315408479835,
#  'disutradarai,VB': 0.0003506311360448808,
#  'David,NNP': 0.0002585315408479835,
#  'Fincher,NNP': 0.0002585315408479835,
#  'pernah,MD': 0.013108614232209739,
#  'menggarap,VB': 0.0003506311360448808,
#  'Fight,NNP': 0.0002585315408479835,
#  "',NNP": 0.0012926577042399173,
#  's,NNP': 0.0012926577042399173,
#  'Club,NNP': 0.0002585315408479835,
#  'sebenarnya,RB': 0.008896797153024912,
#  'memperoleh,VB': 0.0007012622720897616,
#  'izin,NN': 0.0003094059405940594,
#  'Pemuda,NN': 0.0001547029702970297,
#  'berusia,VB': 0.0024544179523141654,
#  '26,CD': 0.002529510961214165,
#  'Saya,PRP': 0.015580736543909348,
#  'mengharapkan,VB': 0.0017531556802244039,
#  'ada,VB': 0.009817671809256662,
#  'membuat,VB': 0.002805049088359046,
#  'tentang,IN': 0.004860804242156429,
#  'saya,PRP': 0.0169971671388102,
#  'ketika,SC': 0.007772020725388601,
#  'masih,MD': 0.11610486891385768,
#  'hidup,VB': 0.0003506311360448808,
#  'konferensi,NN': 0.0001547029702970297,
#  'teknologi,NN': 0.001082920792079208,
#  'Juni,NNP': 0.004136504653567736,
#  'silam,NN': 0.0003094059405940594,
#  'Hingga,IN': 0.0008837825894829872,
#  'Juli,NNP': 0.003360910031023785,
#  '500,CD': 0.0021079258010118043,
#  'juta,CD': 0.023187183811129847,
#  'terdaftar,VB': 0.0007012622720897616,
#  'situs,NN': 0.001082920792079208,
#  'jejaring,NN': 0.0003094059405940594,
#  'sosial,JJ': 0.0027881040892193307,
#  'Hanya,RB': 0.0035587188612099642,
#  'butuh,VB': 0.0007012622720897616,
#  'enam,CD': 0.003372681281618887,
#  'kesuksesan,NN': 0.0006188118811881188,
#  'seperti,SC': 0.0017271157167530224,
#  'sekarang,NN': 0.0007735148514851486,
#  'setelah,SC': 0.02072538860103627,
#  'meluncurkan,VB': 0.0007012622720897616,
#  'saat,SC': 0.004317789291882556,
#  'duduk,VB': 0.0007012622720897616,
#  'sebagai,IN': 0.015908086610693768,
#  'mahasiswa,NN': 0.0001547029702970297,
#  'Universitas,NNP': 0.000517063081695967,
#  'Harvard,NNP': 0.000517063081695967,
#  'September,NNP': 0.0043950361944157185,
#  'majalah,NNP': 0.000517063081695967,
#  'Forbes,NNP': 0.0002585315408479835,
#  'memasukkan,VB': 0.0007012622720897616,
#  'daftar,NN': 0.0003094059405940594,
#  '35,CD': 0.002529510961214165,
#  'Serikat,NNP': 0.0018097207859358842,
#  'dengan,SC': 0.045768566493955096,
#  'total,NN': 0.003094059405940594,
#  'diperkirakan,VB': 0.007363253856942496,
#  'US,NNP': 0.002068252326783868,
#  '$,SYM': 0.00906344410876133,
#  'miliar,CD': 0.050590219224283306,
#  'langkah,NN': 0.001082920792079208,
#  'menuju,VB': 0.001402524544179523,
#  'lah,RP': 0.5555555555555556,
#  'mulus,JJ': 0.0018587360594795538,
#  'orang,NND': 0.013422818791946308,
#  'rekan,NN': 0.0003094059405940594,
#  'mengklaim,VB': 0.001402524544179523,
#  'ide,NN': 0.0001547029702970297,
#  'pembuatan,NN': 0.0006188118811881188,
#  'datang,VB': 0.0010518934081346423,
#  'Mereka,PRP': 0.0084985835694051,
#  'terlibat,VB': 0.0003506311360448808,
#  'sengketa,NN': 0.0001547029702970297,
#  'hukum,NN': 0.001082920792079208,
#  'berlarut-larut,VB': 0.0003506311360448808,
#  '2008,CD': 0.01812816188870152,
#  'diakhiri,VB': 0.0003506311360448808,
#  'pembayaran,NN': 0.001547029702970297,
#  'dirahasiakan,VB': 0.0003506311360448808,
#  'jumlah,NN': 0.0024752475247524753,
#  'Cameron,NNP': 0.0002585315408479835,
#  'Tyler,NNP': 0.0002585315408479835,
#  'Winklevoss,NNP': 0.0002585315408479835,
#  'kini,NN': 0.0007735148514851486,
#  'bernama,VB': 0.0010518934081346423,
#  'ConnectU,NNP': 0.0002585315408479835,
#  'Perebutan,NN': 0.0001547029702970297,
#  'jamrud,NNP': 0.0002585315408479835,
#  'Bahia,NNP': 0.0007755946225439503,
#  'raksasa,JJ': 0.0037174721189591076,
#  'Jaksa,NN': 0.0003094059405940594,
#  'Kalifornia,NNP': 0.000517063081695967,
#  'menanyai,VB': 0.0003506311360448808,
#  'menentukan,VB': 0.0007012622720897616,
#  'mengenai,SC': 0.0008635578583765112,
#  'kepemilikan,NN': 0.0027846534653465345,
#  'jamrud,NN': 0.0006188118811881188,
#  'disebut,VB': 0.001402524544179523,
#  'terbesar,JJ': 0.010223048327137546,
#  'Jamrud,NNP': 0.000517063081695967,
#  'dinamakan,VB': 0.0003506311360448808,
#  'sesuai,JJ': 0.0055762081784386614,
#  'lokasi,NN': 0.0001547029702970297,
#  'penemuan,NN': 0.0001547029702970297,
#  'salah satu,CD': 0.002951096121416526,
#  'daerah,NN': 0.0018564356435643563,
#  'Brasil,NNP': 0.0015511892450879006,
#  'berat,NN': 0.0001547029702970297,
#  '380,CD': 0.00042158516020236085,
#  'kg,NND': 0.013422818791946308,
#  'Diperkirakan,VB': 0.0003506311360448808,
#  'bernilai,VB': 0.0007012622720897616,
#  '370,CD': 0.0008431703204047217,
#  'hak,NN': 0.0004641089108910891,
#  'atas,IN': 0.012814847547503314,
#  'batu,NN': 0.0007735148514851486,
#  'mendengarkan,VB': 0.0007012622720897616,
#  'semua,CD': 0.0042158516020236085,
#  'permata,NN': 0.0003094059405940594,
#  'memutuskan,VB': 0.0017531556802244039,
#  'kasus,NN': 0.0006188118811881188,
#  'berselisih,VB': 0.0003506311360448808,
#  'Anthony,NNP': 0.0002585315408479835,
#  'Thomas,NNP': 0.0007755946225439503,
#  'ahli,NN': 0.0001547029702970297,
#  'konstruksi,NN': 0.001082920792079208,
#  'membayar,VB': 0.0017531556802244039,
#  'agen,NN': 0.0001547029702970297,
#  'senilai,NN': 0.002629950495049505,
#  '60,CD': 0.003372681281618887,
#  'tak,NEG': 0.047244094488188976,
#  'ditemukan,VB': 0.0003506311360448808,
#  'sembilan,CD': 0.002529510961214165,
#  'lalu,NN': 0.0001547029702970297,
#  'mengatur,VB': 0.0003506311360448808,
#  'dikirim,VB': 0.0007012622720897616,
#  'melalui,IN': 0.009279717189571365,
#  'kapal,NN': 0.0009282178217821782,
#  'ke,IN': 0.0273972602739726,
#  'kediaman,NN': 0.0001547029702970297,
#  'San,NNP': 0.0002585315408479835,
#  'Jose,NNP': 0.0002585315408479835,
#  'tetapi,CC': 0.011097410604192354,
#  'muncul,VB': 0.0021037868162692847,
#  'percaya,VB': 0.0003506311360448808,
#  'dicuri,VB': 0.0003506311360448808,
#  'dijual,VB': 0.0010518934081346423,
#  'kembali,RB': 0.046263345195729534,
#  'harga,NN': 0.01021039603960396,
#  'mahal,JJ': 0.0018587360594795538,
#  'hanya,RB': 0.04092526690391459,
#  'pemilik,NN': 0.0007735148514851486,
#  'Satu,CD': 0.0016863406408094434,
#  'masalah,NN': 0.0007735148514851486,
#  'dihadapi,VB': 0.001402524544179523,
#  'kehilangan,VB': 0.0003506311360448808,
#  'tanda terima,NN': 0.0001547029702970297,
#  'akibat,IN': 0.0057445868316394165,
#  'kebakaran,NN': 0.0001547029702970297,
#  'melanda,VB': 0.0003506311360448808,
#  'rumah,NN': 0.0001547029702970297,
#  'Jamrud,NN': 0.0001547029702970297,
#  'akhirnya,RB': 0.0035587188612099642,
#  'sampai,VB': 0.0003506311360448808,
#  'meskipun,SC': 0.0034542314335060447,
#  'setibanya,SC': 0.0008635578583765112,
#  'jelas,JJ': 0.0027881040892193307,
#  'siapa,SC': 0.0025906735751295338,
#  'hal,NN': 0.0027846534653465345,
#  'diketahui,VB': 0.0003506311360448808,
#  'sempat,MD': 0.013108614232209739,
#  'disimpan,VB': 0.0003506311360448808,
#  'lemari besi,NN': 0.0001547029702970297,
#  'bank,NN': 0.0038675742574257425,
#  'New,NNP': 0.002068252326783868,
#  'Orleans,NNP': 0.0002585315408479835,
#  'terkena,VB': 0.0003506311360448808,
#  'banjir,NN': 0.0001547029702970297,
#  'diterjang,VB': 0.0003506311360448808,
#  'Badai,NNP': 0.0002585315408479835,
#  'Katrina,NNP': 0.0002585315408479835,
#  'sehingga,SC': 0.025906735751295335,
#  'berharga,JJ': 0.0009293680297397769,
#  'terendam,VB': 0.0003506311360448808,
#  'dalam,NN': 0.0009282178217821782,
#  'beberapa,CD': 0.008431703204047217,
#  'bulan,NN': 0.006806930693069307,
#  'kemudian,RB': 0.010676156583629894,
#  'dibawa,VB': 0.0003506311360448808,
#  'Las,NNP': 0.0002585315408479835,
#  'Vegas,NNP': 0.0002585315408479835,
#  'dilihat,VB': 0.0010518934081346423,
#  'calon,NN': 0.0004641089108910891,
#  'pembeli,NN': 0.0001547029702970297,
#  'namun,CC': 0.025893958076448828,
#  'disita,VB': 0.0003506311360448808,
#  'polisi,NN': 0.0004641089108910891,
#  'Los,NNP': 0.0002585315408479835,
#  'Angeles,NNP': 0.0002585315408479835,
#  'Badut,NN': 0.0001547029702970297,
#  'politikus,NN': 0.0003094059405940594,
#  'ditantang,VB': 0.0007012622720897616,
#  'baca,VB': 0.0007012622720897616,
#  'tulis,VB': 0.0007012622720897616,
#  'Seorang,NND': 0.026845637583892617,
#  'badut,NN': 0.0003094059405940594,
#  'mempunyai,VB': 0.0024544179523141654,
#  'peluang,NN': 0.0007735148514851486,
#  'meraih,VB': 0.003155680224403927,
#  'kursi,NN': 0.0007735148514851486,
#  'pemilihan,NN': 0.0006188118811881188,
#  'Minggu,NNP': 0.0007755946225439503,
#  '(,Z': 0.001816860465116279,
#  '3,CD': 0.00463743676222597,
#  '/,Z': 0.013808139534883721,
#  '),Z': 0.001816860465116279,
#  '-,Z': 0.0377906976744186,
#  'membuktikan,VB': 0.0010518934081346423,
#  'membaca,VB': 0.0017531556802244039,
#  'menulis,VB': 0.0003506311360448808,
#  'Jajak,NN': 0.0001547029702970297,
#  'pendapat,NN': 0.0001547029702970297,
#  'memperlihatkan,VB': 0.0024544179523141654,
#  'Tiririca,NNP': 0.0012926577042399173,
#  'satu,CD': 0.00463743676222597,
#  'suara,NN': 0.0006188118811881188,
#  'Namun,CC': 0.040690505548705305,
#  'hakim,NN': 0.0001547029702970297,
#  'Sao,NNP': 0.0002585315408479835,
#  'Paulo,NNP': 0.0002585315408479835,
#  'menuntut,VB': 0.0003506311360448808,
#  'memenuhi,VB': 0.0021037868162692847,
#  'persyaratan,NN': 0.0003094059405940594,
#  'Sejumlah,CD': 0.00042158516020236085,
#  'surat kabar,NN': 0.0001547029702970297,
#  'sama,JJ': 0.03531598513011153,
#  'seperti,IN': 0.008395934600088379,
#  'sepuluh,CD': 0.0021079258010118043,
#  'buta aksara,JJ': 0.0009293680297397769,
#  'bahasa sehari-hari,NN': 0.0001547029702970297,
#  'Portugis,NNP': 0.0002585315408479835,
#  'tukang,NN': 0.0001547029702970297,
#  'mengeluh,VB': 0.0003506311360448808,
#  'sensasi,NN': 0.0001547029702970297,
#  'kampanye,NN': 0.0003094059405940594,
#  'Video,NN': 0.0001547029702970297,
#  'kocak,JJ': 0.0009293680297397769,
#  'jutaan,CD': 0.00042158516020236085,
#  'penonton,NN': 0.0004641089108910891,
#  'YouTube,NNP': 0.0015511892450879006,
#  'antara,IN': 0.009721608484312859,
#  'menggunakan,VB': 0.0038569424964936885,
#  'slogan,NN': 0.0001547029702970297,
#  'Tidak,NEG': 0.007874015748031496,
#  'buruk,JJ': 0.0018587360594795538,
#  'lagi,RB': 0.021352313167259787,
#  'Apa,WH': 0.125,
#  'dilakukan,VB': 0.009467040673211781,
#  'wakil,NN': 0.0001547029702970297,
#  'anda,PRP': 0.0028328611898017,
#  '?,Z': 0.0007267441860465116,
#  'Sungguh,RB': 0.0017793594306049821,
#  'tahu,VB': 0.0021037868162692847,
#  'Tapi,CC': 0.004932182490752158,
#  'pilih,VB': 0.0003506311360448808,
#  'mencari tahu,VB': 0.0003506311360448808,
#  'Hakim,NN': 0.0001547029702970297,
#  'menggelar,VB': 0.0003506311360448808,
#  'ujian,NN': 0.0001547029702970297,
#  'aksara,NN': 0.0001547029702970297,
#  'Epoca,NNP': 0.0002585315408479835,
#  'menayangkan,VB': 0.0003506311360448808,
#  'video,NN': 0.0001547029702970297,
#  'tampak,VB': 0.0021037868162692847,
#  'Komisi,NN': 0.0001547029702970297,
#  'terlambat,VB': 0.0003506311360448808,
#  'menghentikan,VB': 0.001402524544179523,
#  'pencalonan,NN': 0.0001547029702970297,
#  'diberhentikan,VB': 0.0003506311360448808,
#  'jika,SC': 0.007772020725388601,
#  'gagal,VB': 0.0007012622720897616,
#  'kemampuan,NN': 0.001082920792079208,
#  'Calon,NN': 0.0003094059405940594,
#  'selebriti,NN': 0.0004641089108910891,
#  'nama,NN': 0.0003094059405940594,
#  'asli,JJ': 0.0055762081784386614,
#  'Francisco,NNP': 0.0002585315408479835,
#  'Everardo,NNP': 0.0002585315408479835,
#  'Oliveira,NNP': 0.0002585315408479835,
#  'Silva,NNP': 0.0002585315408479835,
#  'bekerja,VB': 0.0017531556802244039,
#  'sirkus,NN': 0.0001547029702970297,
#  'delapan,CD': 0.00042158516020236085,
#  'negara bagian,NN': 0.0001547029702970297,
#  'miskin,JJ': 0.0009293680297397769,
#  'Ceara,NNP': 0.0002585315408479835,
#  'Dengan,IN': 0.009279717189571365,
#  'pengalaman,NN': 0.0001547029702970297,
#  'salah seorang,CD': 0.0012647554806070826,
#  'pelawak,NN': 0.0001547029702970297,
#  'terkenal,VB': 0.0010518934081346423,
#  'TV,NN': 0.0007735148514851486,
#  'merupakan,VB': 0.011921458625525946,
#  'puluhan,CD': 0.00042158516020236085,
#  'berasal,VB': 0.0035063113604488078,
#  'olahraga,NN': 0.0007735148514851486,
#  'maupun,CC': 0.01726263871763255,
#  'pertunjukan,NN': 0.0001547029702970297,
#  'berjuang,VB': 0.0003506311360448808,
#  'merebut,VB': 0.0007012622720897616,
#  'majelis rendah,NN': 0.0001547029702970297,
#  'bersaing,VB': 0.0003506311360448808,
#  'melawan,VB': 0.0003506311360448808,
#  'berpengalaman,VB': 0.0003506311360448808,
#  'Seluruhnya,RB': 0.0017793594306049821,
#  'tercatat,VB': 0.0035063113604488078,
#  '6,CD': 0.006323777403035413,
#  '27,CD': 0.0012647554806070826,
#  'partai,NN': 0.0001547029702970297,
#  '513,CD': 0.00042158516020236085,
#  'diduga,VB': 0.0007012622720897616,
#  'kemenangan,NN': 0.0003094059405940594,
#  'mutlak,JJ': 0.0009293680297397769,
#  'Romario,NNP': 0.0002585315408479835,
#  'bintang,NN': 0.0003094059405940594,
#  'sepak bola,NN': 0.0003094059405940594,
#  'Piala,NNP': 0.0007755946225439503,
#  'Dunia,NNP': 0.0043950361944157185,
#  '1994,CD': 0.0008431703204047217,
#  'Para,DT': 0.15,
#  'pengamat,NN': 0.0001547029702970297,
#  'popularitas,NN': 0.0001547029702970297,
#  'mencerminkan,VB': 0.0024544179523141654,
#  'kebingungan,NN': 0.0001547029702970297,
#  'politik,NN': 0.0001547029702970297,
#  'utama,JJ': 0.008364312267657992,
#  'karena,IN': 0.011931064958020326,
#  'marak,JJ': 0.0009293680297397769,
#  'skandal,NN': 0.0001547029702970297,
#  'korupsi,NN': 0.0006188118811881188,
#  'Ibu,NN': 0.0001547029702970297,
#  'bayi,NN': 0.0003094059405940594,
#  'anggota,NN': 0.0007735148514851486,
#  'Parlemen,NNP': 0.000517063081695967,
#  'Eropa,NNP': 0.001034126163391934,
#  'asal,IN': 0.0008837825894829872,
#  'Italia,NNP': 0.000517063081695967,
#  'sidang,NN': 0.0006188118811881188,
#  'Strasbourg,NNP': 0.0002585315408479835,
#  'menggendong,VB': 0.0003506311360448808,
#  'anak,NN': 0.0009282178217821782,
#  'Licia,NNP': 0.0002585315408479835,
#  'Ronzulli,NNP': 0.000517063081695967,
#  'ia,PRP': 0.018413597733711047,
#  'menunjukkan,VB': 0.006661991584852735,
#  'berat,JJ': 0.004646840148698885,
#  'beban,NN': 0.0004641089108910891,
#  'ditanggung,VB': 0.0003506311360448808,
#  'kaum,NN': 0.0001547029702970297,
#  'perempuan,NN': 0.0003094059405940594,
#  'menjalani,VB': 0.0003506311360448808,
#  'karir,NN': 0.0001547029702970297,
#  'sekaligus,RB': 0.0071174377224199285,
#  'mengasuh,VB': 0.0003506311360448808,
#  'sedang,MD': 0.0149812734082397,
#  'membahas,VB': 0.0010518934081346423,
#  'usul,NN': 0.0001547029702970297,
#  'memperbaiki,VB': 0.003155680224403927,
#  'kesempatan,NN': 0.0009282178217821782,
#  'Vittoria,NNP': 0.0002585315408479835,
#  'tidur,VB': 0.0003506311360448808,
#  'nyenyak,JJ': 0.0009293680297397769,
#  'selama,SC': 0.0017271157167530224,
#  'berlangsung,VB': 0.0038569424964936885,
#  'mewakili,VB': 0.0007012622720897616,
#  'Partai,NNP': 0.0002585315408479835,
#  'Kebebasan,NNP': 0.0002585315408479835,
#  'Rakyat,NNP': 0.0002585315408479835,
#  'pimpinan,NN': 0.0003094059405940594,
#  'PM,NNP': 0.0012926577042399173,
#  'Silvio,NNP': 0.0002585315408479835,
#  'Berlusconi,NNP': 0.0002585315408479835,
#  'mendapat,VB': 0.002805049088359046,
#  'sambutan,NN': 0.0001547029702970297,
#  'meriah,JJ': 0.0009293680297397769,
#  'berdiri,VB': 0.0003506311360448808,
#  'menyampaikan,VB': 0.0017531556802244039,
#  'pidato,NN': 0.0004641089108910891,
#  'Ia,PRP': 0.03541076487252125,
#  'sesama,NN': 0.0001547029702970297,
#  'melihat,VB': 0.003155680224403927,
#  'komitmen,NN': 0.0006188118811881188,
#  'persoalan-persoalan,NN': 0.0001547029702970297,
#  'lembaga-lembaga,NN': 0.0001547029702970297,
#  'dimulai,VB': 0.0007012622720897616,
#  'Naskah,NN': 0.0004641089108910891,
#  'Harry,NNP': 0.0007755946225439503,
#  'Potter,NNP': 0.0007755946225439503,
#  'dipamerkan,VB': 0.001402524544179523,
#  'tangan,NN': 0.0001547029702970297,
#  'pengarang,NN': 0.0003094059405940594,
#  'JK,NNP': 0.0007755946225439503,
#  'Rowling,NNP': 0.0007755946225439503,
#  'festival,NN': 0.0004641089108910891,
#  'buku,NN': 0.001082920792079208,
#  'Skotlandia,NNP': 0.0007755946225439503,
#  'selatan,NNP': 0.0002585315408479835,
#  'halaman,NND': 0.006711409395973154,
#  'naskah,NN': 0.0004641089108910891,
#  'dibingkai,VB': 0.0003506311360448808,
#  'ditandatangani,VB': 0.0007012622720897616,
#  'berisi,VB': 0.0003506311360448808,
#  'Balada,NN': 0.0003094059405940594,
#  'Nick,NNP': 0.0007755946225439503,
#  'Si,DT': 0.05,
#  'Kepala,NN': 0.0012376237623762376,
#  'Nyaris,RB': 0.0035587188612099642,
#  'Putus,VB': 0.0007012622720897616,
#  'Wigtown,NNP': 0.000517063081695967,
#  '24,CD': 0.002529510961214165,
#  'sampai,IN': 0.010605391073795847,
#  'hantu,NN': 0.0001547029702970297,
#  'awal,NN': 0.0029393564356435644,
#  'Kamar,NN': 0.0001547029702970297,
#  'Rahasia,NN': 0.0001547029702970297,
#  'kemudian,CC': 0.007398273736128237,
#  'kedua,CD': 0.003372681281618887,
#  'halaman,NN': 0.0007735148514851486,
#  'dibuang,VB': 0.0003506311360448808,
#  'termasuk,VB': 0.0070126227208976155,
#  'diterbitkan,VB': 0.0038569424964936885,
#  'disumbangkan,VB': 0.0007012622720897616,
#  'Yayasan,NNP': 0.0002585315408479835,
#  'Kamus,NNP': 0.0002585315408479835,
#  'Bahasa,NNP': 0.000517063081695967,
#  '2005,CD': 0.007588532883642495,
#  'mendukung,VB': 0.0035063113604488078,
#  'pengumpulan,NN': 0.0001547029702970297,
#  'dana,NN': 0.004022277227722772,
#  'kamus,NN': 0.0001547029702970297,
#  'baru,JJ': 0.013940520446096654,
#  'bahasa,NN': 0.0001547029702970297,
#  'Sekarang,NN': 0.0003094059405940594,
#  'dimiliki,VB': 0.003155680224403927,
#  'kolektor,NN': 0.0001547029702970297,
#  'terkemuka,JJ': 0.0009293680297397769,
#  'Inggris,NNP': 0.0038779731127197518,
#  'jurnal,NNP': 0.0002585315408479835,
#  'Asia,NNP': 0.0031023784901758012,
#  'Literary,NNP': 0.000517063081695967,
#  'Review,NNP': 0.000517063081695967,
#  'Ilyas,NNP': 0.000517063081695967,
#  'Khan,NNP': 0.000517063081695967,
#  'umum,NN': 0.0001547029702970297,
#  'senang,JJ': 0.0009293680297397769,
#  'ikut,VB': 0.0007012622720897616,
#  'Festival,NNP': 0.0002585315408479835,
#  'Memamerkan,VB': 0.0003506311360448808,
#  'si,DT': 0.15,
#  'cara,NN': 0.0006188118811881188,
#  'bagus,JJ': 0.0037174721189591076,
#  'Australia,NNP': 0.0015511892450879006,
#  'salah,JJ': 0.0018587360594795538,
#  'sebut,VB': 0.0003506311360448808,
#  'pemenang,NN': 0.0009282178217821782,
#  'Acara,NN': 0.0001547029702970297,
#  'Next,NNP': 0.0002585315408479835,
#  'Top,NNP': 0.0002585315408479835,
#  'Model,NNP': 0.0002585315408479835,
#  'mengumumkan,VB': 0.001402524544179523,
#  'final,NN': 0.0004641089108910891,
#  'disiarkan,VB': 0.0003506311360448808,
#  'langsung,RB': 0.021352313167259787,
#  'seri,NN': 0.0013923267326732673,
#  'keenam,OD': 0.030612244897959183,
#  'Kelsey,NNP': 0.0002585315408479835,
#  'Martinovich,NNP': 0.000517063081695967,
#  'dianugerahi,VB': 0.0003506311360448808,
#  'mahkota,NN': 0.0001547029702970297,
#  'pilihan,NN': 0.0001547029702970297,
#  'pemirsa,NN': 0.0001547029702970297,
#  'presenter,NNP': 0.0002585315408479835,
#  'Sarah,NNP': 0.001034126163391934,
#  'Murdoch,NNP': 0.001034126163391934,
#  'menyela,VB': 0.0003506311360448808,
#  'Sambil,SC': 0.0008635578583765112,
#  'menggeleng-gelengkan,VB': 0.0003506311360448808,
#  'kepala,NN': 0.0001547029702970297,
#  'ear,FW': 0.0023752969121140144,
#  'piece,FW': 0.0023752969121140144,
#  'mual,JJ': 0.0009293680297397769,
#  'amat,RB': 0.0017793594306049821,
#  'meminta,VB': 0.002805049088359046,
#  'maaf,NN': 0.0001547029702970297,
#  'semata-mata,RB': 0.0035587188612099642,
#  'kecelakaan,NN': 0.0001547029702970297,
#  'yaitu,SC': 0.016407599309153715,
#  'Amanda,NNP': 0.000517063081695967,
#  'Ware,NNP': 0.000517063081695967,
#  '18,CD': 0.003372681281618887,
#  'Ini,PR': 0.01968503937007874,
#  'terjadi,VB': 0.009817671809256662,
#  'kalau,SC': 0.004317789291882556,
#  'siaran,NN': 0.0001547029702970297,
#  'edan,JJ': 0.0027881040892193307,
#  'Adapun,CC': 0.0012330456226880395,
#  'sekitar,RB': 0.06227758007117438,
#  'menit,NND': 0.006711409395973154,
#  'menerima,VB': 0.0017531556802244039,
#  'kesalahan,NN': 0.0001547029702970297,
#  'baik,JJ': 0.026022304832713755,
#  'Ok,FW': 0.0023752969121140144,
#  'kekeliruan,NN': 0.0003094059405940594,
#  'berusaha,VB': 0.0010518934081346423,
#  'menjelaskan,VB': 0.00455820476858345,
#  'selisih,NN': 0.0004641089108910891,
#  'ketat,JJ': 0.0037174721189591076,
#  'Yang,DT': 0.15,
#  'memimpin,VB': 0.0003506311360448808,
#  'terus-menerus,RB': 0.0035587188612099642,
#  'berganti,VB': 0.0003506311360448808,
#  'Benar-benar,RB': 0.0017793594306049821,
#  'tergantung,VB': 0.0010518934081346423,
#  'Maju,VB': 0.0003506311360448808,
#  'mundur,VB': 0.0003506311360448808,
#  '-nya,PRP': 0.009915014164305949,
#  'jelas,VB': 0.003155680224403927,
#  'finalis,NN': 0.0001547029702970297,
#  'berpelukan,VB': 0.0003506311360448808,
#  'mengucapkan,VB': 0.0003506311360448808,
#  'terima kasih,NN': 0.0001547029702970297,
#  'pendukung,NN': 0.0003094059405940594,
#  'berjalan,VB': 0.0035063113604488078,
#  'atas,NN': 0.0017017326732673267,
#  'catwalk,FW': 0.0023752969121140144,
#  'terakhir,OD': 0.01020408163265306,
#  'kali,NND': 0.040268456375838924,
#  'Dan,CC': 0.002466091245376079,
#  'model,NN': 0.0003094059405940594,
#  'merangkap,VB': 0.0003506311360448808,
#  'presenter,FW': 0.0023752969121140144,
#  'menikah,VB': 0.0003506311360448808,
#  'putra,NN': 0.0001547029702970297,
#  'Rupert,NNP': 0.0002585315408479835,
#  'Lachlan,NNP': 0.0002585315408479835,
#  'Membaca,VB': 0.0003506311360448808,
#  'Don,NNP': 0.0007755946225439503,
#  'Quixote,NNP': 0.0007755946225439503,
#  'Akademi,NNP': 0.000517063081695967,
#  'Kerajaan,NNP': 0.001034126163391934,
#  'Spanyol,NNP': 0.0018097207859358842,
#  'mengundang,VB': 0.0003506311360448808,
#  'merekam,VB': 0.0003506311360448808,
#  'segmen,NN': 0.0012376237623762376,
#  'novel,NN': 0.0006188118811881188,
#  'klasik,JJ': 0.0018587360594795538,
#  'mengunggah,VB': 0.0003506311360448808,
#  'Karya,NN': 0.0001547029702970297,
#  'Miguel,NNP': 0.0002585315408479835,
#  'de,NNP': 0.0002585315408479835,
#  'Cervantes,NNP': 0.0002585315408479835,
#  'paling,RB': 0.010676156583629894,
#  'populer,JJ': 0.0009293680297397769,
#  'walau,SC': 0.0008635578583765112,
#  'pelindung,NN': 0.0001547029702970297,
#  'bahasa,NNP': 0.0007755946225439503,
#  'membagi,VB': 0.0003506311360448808,
#  'karya,NN': 0.0004641089108910891,
#  '2,CD': 0.002951096121416526,
#  'Segmen-segmen,NN': 0.0001547029702970297,
#  'dibaca,VB': 0.0003506311360448808,
#  'direkam,VB': 0.0003506311360448808,
#  'sukarelawan,NN': 0.0001547029702970297,
#  'diunggah,VB': 0.0007012622720897616,
#  'Tujuan,NN': 0.0001547029702970297,
#  'mempromosikan,VB': 0.0003506311360448808,
#  'lengkap,JJ': 0.0018587360594795538,
#  'Ingenious,NNP': 0.0002585315408479835,
#  'Hidalgo,NNP': 0.0002585315408479835,
#  'of,NNP': 0.0018097207859358842,
#  'La,NNP': 0.0002585315408479835,
#  'Mancha,NNP': 0.000517063081695967,
#  'ruang,NN': 0.0003094059405940594,
#  'sepatutnya,RB': 0.0017793594306049821,
#  'internet,NN': 0.0001547029702970297,
#  'sekretaris,NN': 0.0001547029702970297,
#  'akademi,NN': 0.0001547029702970297,
#  'Dario,NNP': 0.0002585315408479835,
#  'Villanueva,NNP': 0.0002585315408479835,
#  'Kami,PRP': 0.009915014164305949,
#  'mengadukan,VB': 0.0003506311360448808,
#  'melakukan,VB': 0.010518934081346423,
#  'sesuatu,PRP': 0.00424929178470255,
#  'mengoreksi,VB': 0.0003506311360448808,
#  'Ditulis,VB': 0.0003506311360448808,
#  '1605,CD': 0.00042158516020236085,
#  'berkisah,VB': 0.0003506311360448808,
#  'petualangan,NN': 0.0001547029702970297,
#  'pria,NN': 0.0004641089108910891,
#  'pensiunan,NN': 0.0001547029702970297,
#  'kawasan,NN': 0.0004641089108910891,
#  'la,NNP': 0.0002585315408479835,
#  'punya,VB': 0.0007012622720897616,
#  'obsesi,NN': 0.0001547029702970297,
#  'gagasan-gagasan,NN': 0.0001547029702970297,
#  'kesatria,NN': 0.0001547029702970297,
#  'Novel,NN': 0.0001547029702970297,
#  'terdiri,VB': 0.006311360448807854,
#  'bab,NN': 0.0001547029702970297,
#  'hampir,RB': 0.005338078291814947,
#  '1,CD': 0.006745362563237774,
#  'Bagi,IN': 0.0004418912947414936,
#  'berminat,VB': 0.0003506311360448808,
#  'mendaftarkan,VB': 0.0003506311360448808,
#  'terpilih,VB': 0.0003506311360448808,
#  'tertentu,JJ': 0.0037174721189591076,
#  'Hobbit,NNP': 0.0007755946225439503,
#  'cari,VB': 0.0003506311360448808,
#  'aktor,NN': 0.0009282178217821782,
#  'kerdil,JJ': 0.0018587360594795538,
#  'Tim,NN': 0.0004641089108910891,
#  'pembuat,NN': 0.0003094059405940594,
#  'mencari,VB': 0.0017531556802244039,
#  'Selandia,NNP': 0.000517063081695967,
#  'Baru,NNP': 0.000517063081695967,
#  'sementara,SC': 0.0051813471502590676,
#  'sutradara,NNP': 0.0002585315408479835,
#  'Peter,NNP': 0.000517063081695967,
#  'Jackson,NNP': 0.0007755946225439503,
#  'berancang-ancang,VB': 0.0003506311360448808,
#  'merealisasikan,VB': 0.0003506311360448808,
#  'rencana,NN': 0.004176980198019802,
#  'Sutradara,NNP': 0.0002585315408479835,
#  'Oscar,NNP': 0.000517063081695967,
#  'Lord,NNP': 0.0007755946225439503,
#  'the,NNP': 0.001034126163391934,
#  'Rings,NNP': 0.0007755946225439503,
#  ':,NNP': 0.000517063081695967,
#  'Return,NNP': 0.000517063081695967,
#  'King,NNP': 0.0007755946225439503,
#  'Iklan,NN': 0.0001547029702970297,
#  'koran,NN': 0.0001547029702970297,
#  'terbitan,NN': 0.0001547029702970297,
#  'Wellington,NNP': 0.000517063081695967,
#  'Wingnut,NNP': 0.000517063081695967,
#  'Films,NNP': 0.0002585315408479835,
#  'tinggi,NN': 0.0007735148514851486,
#  'badan,NN': 0.0009282178217821782,
#  '123,CD': 0.00042158516020236085,
#  'cm,NND': 0.03355704697986577,
#  'maksimum,NN': 0.0003094059405940594,
#  '158,CD': 0.00042158516020236085,
#  'Proyek,NN': 0.0001547029702970297,
#  'lampu hijau,NN': 0.0001547029702970297,
#  'perusahaan,NN': 0.008199257425742575,
#  'perfilman,NN': 0.0001547029702970297,
#  'MGM,NNP': 0.0002585315408479835,
#  'Studios,NNP': 0.0002585315408479835,
#  'kesulitan,NN': 0.0003094059405940594,
#  'keuangan,NN': 0.0049504950495049506,
#  'tengah,MD': 0.009363295880149813,
#  'dialami,VB': 0.0003506311360448808,
#  'juru bicara,NNP': 0.0002585315408479835,
#  'bersiap-siap,VB': 0.0003506311360448808,
#  'Juru bicara,NN': 0.0003094059405940594,
#  'iklan,NN': 0.0001547029702970297,
#  'scale,FW': 0.0023752969121140144,
#  'double,FW': 0.007125890736342043,
#  'mengisi,VB': 0.0007012622720897616,
#  'peran,NN': 0.0003094059405940594,
#  'dialog,NN': 0.0004641089108910891,
#  'sedangkan,CC': 0.025893958076448828,
#  'audisi,NN': 0.0001547029702970297,
#  'diadakan,VB': 0.0007012622720897616,
#  'figuran,NN': 0.0001547029702970297,
#  'Scale,FW': 0.0023752969121140144,
#  'wide,FW': 0.0023752969121140144,
#  'shot,FW': 0.0023752969121140144,
#  'pengganti,NN': 0.0001547029702970297,
#  'dewasa,JJ': 0.0018587360594795538,
#  ...}
