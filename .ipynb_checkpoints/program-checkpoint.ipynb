# %% [markdown]
# ## <center>Natural Language Processing (Tugas 2)</center>
# <strong> NIM  : 1301178418 </strong><br>
# <strong> Nama : Bastomy </strong> <br>
# <strong> Kelas : ICM-39-GAB </strong>

# %% [markdown]
# #### Deskripsi Tugas

# %% [markdown]
# Deskripsi
# Buatlah program yang mengimplementasikan dua pendekatan POS-tagging. Sebagai input adalah
# kalimat Bahasa Indonesia and output adalah kalimat setelah setiap katanya diberi tag yang tepat.
# Kedua pendekatan yang harus diimplementasikan adalah:
# 1. Baseline (menggunakan POS Tag yang paling sering muncul)
# 2. HMM.

# %% [markdown]
# ### Import library

# %%
import pandas as pd
import re
import operator

# %% [markdown]
# <strong>pandas</strong> =  untuk mempermudah membuat array menjadi data tabel <br>
# <strong>re</strong> = regular expression untuk membagi string menjadi array berdasarkan tab (\t) <br>
# <strong>operator</strong> = untuk mengambil item

# %% [markdown]
# ### Fungsi untuk membaca data training dan testing menjadi array

# %%
def read_data(train):
    dt_train = {'kata':[], 'tag':[]}
    for line in open(train):
        if not line.startswith('<kalimat') and not line.startswith('</kalimat'):
            baris = re.split(r'\t+', line.rstrip('\t'))
            dt_train['kata'].append(baris[0].lower())
            dt_train['tag'].append(baris[1].replace('\n',''))
    data = pd.DataFrame(dt_train)        
    return data

# %% [markdown]
# read_data adalah fungsi untuk membaca data .txt menjadi sebuah array <br>
# terdapat dua kolom array yaitu kata dan tag  <br>
# setiap baris data akan di looping dan di cek jika tidak berawalan <kalimat dan </kalimat maka akan lanjut ke tahap berikutnya yaitu membagi setiap baris menjadi array berdasarkan \t (Tab) <br>
# kemudian akan di simpan ke dt_train dan di set menjadi Dataframe untuk di return

# %% [markdown]
# ### Fungsi untuk menghitung jumlah tag berdasarkan kata

# %%
def post_tag_frequency(kata, data_training):
    hitungTag = data_training.loc[data_training['kata'] == kata]['tag'].value_counts()
    if(len(hitungTag) == 0):
        return 'NN','0'
    tagTerbaik = max(hitungTag.items(),key=operator.itemgetter(1))
    return tagTerbaik[0],tagTerbaik[1]

# %% [markdown]
# Menghitung jumlah tag berdasarkan kata  <br>
# variabel hitungTag akan menyimpan jumlah tag berdasarkan kata  <br>
# jika tag bernilai 0 maka akan di terun tag NN dengan jumlah 0  (untuk menghandle kata yg tidak terdaftar)<br>
# kemudian akan dicari max dari tag yg tersedia  <br>
# fungsi akan mengembalikan Tag dan jumlah tag nya <br>
# contoh (PRP   44) <br>

# %% [markdown]
# ### Fungsi prediksi tag BASELINE

# %%
def baseline(data_testing,data_training):
    index = 0 
    tag_correct = 0
    result = {'kata':[], 'prediksi':[], 'tag':[]}
    akurasi = 0
    for i in data_testing['kata']:
        tag,count = post_tag_frequency(i, data_training)
        if(tag == data_testing['tag'][index]):
            tag_correct+=1
        result['kata'].append(i)
        result['prediksi'].append(tag)
        result['tag'].append(data_testing['tag'][index])
        index+=1
    data = pd.DataFrame(result)
    akurasi = (tag_correct/index)*100
    return data,akurasi

# %% [markdown]
# Baseline akan memprediksi Tag berdasarkan kemunculan terbanyak <br>
# cara kerja fungsi diatas adalah melooping semua kata beserta Tag <br>
# kemudian kata tersebut akan diprediksi Tag nya berdasarkan data training <br>
# post_tag_frequency akan mengembalikan tag beserta jumlahnya kemunculannya, tag dari post_tag_frequency akan dijadikan prediksi <br>
# akurasi dihitung dari jumlah tag yg benar dibagi dengan total seluruh kata

# %% [markdown]
# ### Read Data

# %%
dt_training = read_data('corpus/training.txt')
dt_testing = read_data('corpus/testing.txt')

# %% [markdown]
# simpan data training dan testing kedalam variabel

# %% [markdown]
# ### NO 1. Baseline (menggunakan POS Tag yang paling sering muncul)

# %%
data, akurasi = baseline(dt_testing,dt_training)

# %% [markdown]
# Data testing dan prediksi TAG

# %%
data

# %% [markdown]
# Akurasi Tag (persen)

# %%
akurasi

# %% [markdown]
# ### No 2 HMM

# %% [markdown]
# ### Import library

# %%
from nltk import word_tokenize
from sklearn import tree
from sklearn.feature_extraction import DictVectorizer
from sklearn.pipeline import Pipeline
import time

# %% [markdown]
# import library yang akan digunakan seperti :<br>
# <strong>word_tokenize</strong> : untuk membuat kalimat menjadi token<br>
# <strong>tree</strong> : untuk membuat DecisionTreeClassifier<br>
# <strong>DictVectorizer</strong> : untuk merubah feature menjadi matrix vektor<br>
# <strong>time</strong> : untuk menghitung lama program di eksekusi<br>

# %% [markdown]
# ### Fungsi untuk mengekstrak data menjadi kalimat + tag

# %%
def read_data_sentences(data):
    sentences = []
    tags = []
    with open(data) as f:
        content = f.readlines()
    contents = [x.strip() for x in content]
    sentence = []
    tag = []
    for i in contents:
        if not i.startswith('<kalimat') and not i.startswith('</kalimat'):
            content_part = i.split('\t')
            if (len(content_part)==2):
                sentence.append(content_part[0])
                tag.append(content_part[1])
        elif i.startswith('</kalimat'):
            sentences.append(sentence)
            tags.append(tag)
            sentence = []
            tag = []
    return sentences,tags

# %% [markdown]
# <strong>Contoh:</strong> <br>
# <table style="border: 1px solid black;">
# 	<tr style="border: 1px solid black;">
# 		<td style="border: 1px solid black;" style="border: 1px solid black;">Kalimat</td>
# 		<td style="border: 1px solid black;">namun</td>
# 		<td style="border: 1px solid black;">laba</td>
# 		<td style="border: 1px solid black;">usaha</td>
# 		<td style="border: 1px solid black;">dalam</td>
# 		<td style="border: 1px solid black;">periode</td>
# 		<td style="border: 1px solid black;">tersebut</td>
# 		<td style="border: 1px solid black;">menyusut</td>
# 		<td style="border: 1px solid black;">dari</td>
# 		<td style="border: 1px solid black;">semula</td>
# 		<td style="border: 1px solid black;">Rp</td>
# 		<td style="border: 1px solid black;">58,27</td>
# 		<td style="border: 1px solid black;">miliar</td>
# 		<td style="border: 1px solid black;">menjadi</td>
# 		<td style="border: 1px solid black;">Rp</td>
# 		<td style="border: 1px solid black;">41,39</td>
# 		<td style="border: 1px solid black;">miliar</td>
# 		<td style="border: 1px solid black;">.</td>
# 	</tr>
# 	<tr style="border: 1px solid black;">
# 		<td style="border: 1px solid black;" style="border: 1px solid black;">Tag</td>
# 		<td style="border: 1px solid black;">CC</td>
# 		<td style="border: 1px solid black;">NN</td>
# 		<td style="border: 1px solid black;">NN</td>
# 		<td style="border: 1px solid black;">IN</td>
# 		<td style="border: 1px solid black;">NN</td>
# 		<td style="border: 1px solid black;">PR</td>
# 		<td style="border: 1px solid black;">VB</td>
# 		<td style="border: 1px solid black;">IN</td>
# 		<td style="border: 1px solid black;">NN</td>
# 		<td style="border: 1px solid black;">SYM</td>
# 		<td style="border: 1px solid black;">CD</td>
# 		<td style="border: 1px solid black;">CD</td>
# 		<td style="border: 1px solid black;">VB</td>
# 		<td style="border: 1px solid black;">SYM</td>
# 		<td style="border: 1px solid black;">CD</td>
# 		<td style="border: 1px solid black;">CD</td>
# 		<td style="border: 1px solid black;">Z</td>
# 	</tr>
# </table>

# %%
def extract_features(sentence, index):
    return {
        'word': sentence[index],
        'prefix-1': sentence[index][0],
        'prefix-2': sentence[index][:2],
        'prefix-3': sentence[index][:3],
        'suffix-1': sentence[index][-1],
        'suffix-2': sentence[index][-2:],
        'suffix-3': sentence[index][-3:],
        'prev_word': '' if index == 0 else sentence[index - 1],
        'next_word': '' if index == len(sentence) - 1 else sentence[index + 1],
    }

# %%
def transform_to_dataset(sentences, tags):
    X, y = [], []
    for sentence_idx in range(len(sentences)):
        for index in range(len(sentences[sentence_idx])):
            X.append(extract_features(sentences[sentence_idx], index))
            y.append(tags[sentence_idx][index])
    return X, y

# %%
training_sentences,training_tags = read_data_sentences('corpus/training.txt')
testing_sentences,testing_tags = read_data_sentences('corpus/testing.txt')

# %%
X, y = transform_to_dataset(training_sentences, training_tags)

# %%
start = time.time()
clf = Pipeline([
    ('vectorizer', DictVectorizer(sparse=False)),
    ('classifier', tree.DecisionTreeClassifier(criterion='entropy'))
])
clf.fit(X, y)
finish = time.time()
print('Training completed in ',finish-start,' seconds')
# Out:
# Training completed in  396.23731422424316  seconds

# %%
X_test, y_test = transform_to_dataset(testing_sentences, testing_tags)
 
print("Accuracy:")
print(clf.score(X_test, y_test)*100,'persen')
# Out:
# Accuracy:
# 94.98997995991984 persen

# %%
# Test model yang sudah dilatih dengan kalimat masukan bebas
from nltk import word_tokenize

def pos_tag(sentence):
    tags = clf.predict([extract_features(sentence, index) for index in range(len(sentence))])
    data = pd.DataFrame({"kata":sentence,'tag':tags})
    return data

# %%
result = pos_tag(word_tokenize('Pemerintah Kabupaten Serang memberikan insentif kepada 1.796 Kader Pos Keluarga Berencana dan Kader Subpos KB. Bupati Serang Ratu Tatu Chasanah mengatakan hal tersebut sebagai apresiasi kader yang terus berupaya mengendalikan laju pertumbuhan penduduk di Kabupaten Serang'))

# %%
result
# Out:
#              kata  tag
# 0      Pemerintah   NN
# 1       Kabupaten  NNP
# 2          Serang  NNP
# 3      memberikan   VB
# 4        insentif   JJ
# 5          kepada   IN
# 6           1.796   CD
# 7           Kader  NNP
# 8             Pos  NNP
# 9        Keluarga  NNP
# 10      Berencana  NNP
# 11            dan   CC
# 12          Kader  NNP
# 13         Subpos  NNP
# 14             KB  NNP
# 15              .    Z
# 16         Bupati  NNP
# 17         Serang  NNP
# 18           Ratu  NNP
# 19           Tatu  NNP
# 20       Chasanah   NN
# 21     mengatakan   VB
# 22            hal   NN
# 23       tersebut   PR
# 24        sebagai   IN
# 25      apresiasi   NN
# 26          kader   NN
# 27           yang   SC
# 28          terus   RB
# 29       berupaya   VB
# 30  mengendalikan   VB
# 31           laju   NN
# 32    pertumbuhan   NN
# 33       penduduk   NN
# 34             di   IN
# 35      Kabupaten  NNP
# 36         Serang  NNP

# %%
def read_file_init_table(fname):
    tag_count = {}
    tag_count['<start>'] = 0
    word_tag = {}
    tag_trans = {}
    with open(fname) as f:
        content = f.readlines()
    # you may also want to remove whitespace characters like `\n` at the end of each line
    content = [x.strip() for x in content]
    idx_line = 0
    is_first_word = 0
    
    while idx_line < len(content):
        prev_tag = '<start>'
        while not content[idx_line].startswith('</kalimat'):
            if  not content[idx_line].startswith('<kalimat'):
                content_part = content[idx_line].split('\t')
                if content_part[1] in tag_count:
                    tag_count[content_part[1]] += 1
                else:
                    tag_count[content_part[1]] = 1
                    
                current_word_tag = content_part[0]+','+content_part[1]
                if current_word_tag in word_tag:
                    word_tag[current_word_tag] += 1
                else:    
                    word_tag[current_word_tag] = 1
                    
                if is_first_word == 1:
                    current_tag_trans = '<start>,'+content_part[1]
                    is_first_word = 0
                else:
                    current_tag_trans = prev_tag+','+content_part[1]
                    
                if current_tag_trans in tag_trans:
                    tag_trans[current_tag_trans] += 1
                else:
                    tag_trans[current_tag_trans] = 1                    
                prev_tag = content_part[1]   
                
            else:
                tag_count['<start>'] += 1
                is_first_word = 1
            idx_line = idx_line + 1

        idx_line = idx_line+1       
    return tag_count, word_tag, tag_trans

# %%
tag_count, word_tag, tag_trans = read_file_init_table('corpus/training.txt')

# %%
word_tag
# Out:
# {'Kera,NN': 1,
#  'untuk,SC': 126,
#  'amankan,VB': 1,
#  'pesta olahraga,NN': 1,
#  'Pemerintah,NNP': 2,
#  'kota,NNP': 3,
#  'Delhi,NNP': 5,
#  'mengerahkan,VB': 1,
#  'monyet,NN': 12,
#  'mengusir,VB': 4,
#  'monyet-monyet,NN': 2,
#  'lain,JJ': 29,
#  'yang,SC': 538,
#  'berbadan,VB': 2,
#  'lebih,RB': 80,
#  'kecil,JJ': 14,
#  'dari,IN': 251,
#  'arena,NN': 2,
#  'Pesta Olahraga,NNP': 1,
#  'Persemakmuran,NNP': 1,
#  '.,Z': 1012,
#  'Beberapa,CD': 1,
#  'laporan,NN': 15,
#  'menyebutkan,VB': 10,
#  'setidaknya,RB': 2,
#  '10,CD': 21,
#  'ditempatkan,VB': 2,
#  'di,IN': 360,
#  'luar,NN': 5,
#  'lomba,NN': 1,
#  'dan,CC': 481,
#  'pertandingan,NN': 1,
#  'ibukota,NNP': 2,
#  'India,NNP': 6,
#  'Pemkot,NNP': 1,
#  'memiliki,VB': 20,
#  '28,CD': 6,
#  'berencana,VB': 9,
#  'mendatangkan,VB': 2,
#  'sejenis,NN': 1,
#  'negara bagian,NNP': 1,
#  'Rajasthan,NNP': 1,
#  'Jumlah,NN': 5,
#  'mencapai,VB': 97,
#  'ribuan,CD': 1,
#  '",",Z': 1393,
#  'sebagian besar,NN': 3,
#  'berada,VB': 14,
#  'kantor-kantor,NN': 1,
#  'pemerintah,NN': 52,
#  'hewan,NN': 1,
#  'ini,PR': 199,
#  'dianggap,VB': 4,
#  'mengganggu,VB': 3,
#  'ketertiban,NN': 1,
#  'umum,JJ': 9,
#  'Jenis,NN': 1,
#  'dikerahkan,VB': 3,
#  'pemkot,NN': 1,
#  'besar,JJ': 33,
#  'berekor,VB': 1,
#  'panjang,JJ': 4,
#  'wajah,NN': 1,
#  'berwarna,VB': 1,
#  'hitam,JJ': 1,
#  'Monyet,NN': 3,
#  'diikat,VB': 1,
#  'dengan,IN': 176,
#  'tali,NN': 2,
#  'pelatih,NN': 1,
#  'mengawasi,VB': 2,
#  'mereka,PRP': 23,
#  'akan,MD': 192,
#  'melepas,VB': 4,
#  'begitu,SC': 1,
#  'mendekat,VB': 1,
#  'Kantor,NNP': 6,
#  'berita,NNP': 1,
#  'AFP,NNP': 4,
#  'melaporkan,VB': 4,
#  'stadion,NN': 3,
#  'tinju,NN': 1,
#  'hockey,FW': 1,
#  'mendapatkan,VB': 3,
#  'perhatian,NN': 2,
#  'khusus,JJ': 13,
#  'karena,SC': 41,
#  'sering,RB': 3,
#  'diserbu,VB': 1,
#  'dua,CD': 21,
#  'serbuan,NN': 2,
#  '",Z': 70,
#  'tersebut,PR': 118,
#  ',,Z': 32,
#  'kata,VB': 164,
#  'Devender,NNP': 1,
#  'Prasad,NNP': 1,
#  'pejabat,NN': 3,
#  'pemerintah,NNP': 6,
#  'kepada,IN': 56,
#  'kantor berita,NNP': 3,
#  'Selama,IN': 3,
#  'bertahun-tahun,CD': 1,
#  'warga,NN': 2,
#  'Binatang,NN': 2,
#  'menaiki,VB': 1,
#  'kereta,NN': 1,
#  'metro,NN': 1,
#  'bahkan,RB': 8,
#  'berkeliaran,VB': 1,
#  'kompleks,NN': 1,
#  'gedung,NN': 1,
#  'parlemen,NN': 11,
#  'Belum,NEG': 1,
#  'lama,JJ': 2,
#  'kawanan,NN': 3,
#  'menyerbu,VB': 1,
#  'kantor,NN': 2,
#  'perdana menteri,NN': 3,
#  'departemen,NN': 3,
#  'pertahanan,NN': 1,
#  'tidak,NEG': 81,
#  'bisa,MD': 42,
#  'dibunuh,VB': 1,
#  'masyarakat,NN': 12,
#  'menganggap,VB': 2,
#  'suci,JJ': 1,
#  'Selain,CC': 1,
#  'harus,MD': 15,
#  'pemkot,NNP': 1,
#  'juga,RB': 75,
#  'kesulitan,VB': 3,
#  'mengatasi,VB': 5,
#  'wabah,NN': 1,
#  'demam berdarah,NN': 1,
#  'Curah,NN': 1,
#  'hujan,NN': 1,
#  'tinggi,JJ': 33,
#  'menyebabkan,VB': 5,
#  'banyak,CD': 22,
#  'genangan,NN': 2,
#  'tempat,NN': 5,
#  'ideal,JJ': 2,
#  'bagi,IN': 22,
#  'nyamuk,NN': 2,
#  'aedes,NNP': 1,
#  'berkembang biak,VB': 1,
#  'Pemkot,NN': 1,
#  'telah,MD': 72,
#  'menempatkan,VB': 2,
#  'ikan,NN': 1,
#  'berbagai,CD': 10,
#  'air,NN': 5,
#  'memangsa,VB': 1,
#  'telur,NN': 1,
#  'Miliarder,NN': 1,
#  'AS,NNP': 153,
#  'jamu,VB': 1,
#  'orang kaya,NN': 1,
#  'Cina,NNP': 6,
#  'Dua,CD': 3,
#  'miliarder,NN': 2,
#  'Amerika,NNP': 13,
#  'Bill,NNP': 1,
#  'Gates,NNP': 2,
#  'Warren,NNP': 1,
#  'Buffett,NNP': 2,
#  'mengadakan,VB': 3,
#  'jamuan,NN': 3,
#  'makan malam,NN': 3,
#  'Beijing,NNP': 1,
#  'sejumlah,CD': 6,
#  'orang,NN': 16,
#  'terkaya,JJ': 3,
#  'mengatakan,VB': 92,
#  'mempelajari,VB': 1,
#  'kegiatan,NN': 5,
#  'amal,NN': 5,
#  'negara,NN': 50,
#  'itu,PR': 146,
#  'Banyak,CD': 3,
#  'menduga,VB': 1,
#  'ingin,RB': 7,
#  'membujuk,VB': 2,
#  'para,DT': 9,
#  'tamu,NN': 2,
#  'agar,SC': 9,
#  'menyumbang,VB': 4,
#  'untuk,IN': 102,
#  'Kedua,CD': 3,
#  'dunia,NN': 21,
#  'sudah,MD': 32,
#  'berhasil,VB': 11,
#  'sangat,RB': 25,
#  'kaya,JJ': 2,
#  'menyumbangkan,VB': 2,
#  'separuh,CD': 1,
#  'kekayaan,NN': 3,
#  'Ada,VB': 1,
#  'kerahasiaan,NN': 1,
#  'mengenai,IN': 8,
#  'acara,NN': 6,
#  'pihak,NN': 25,
#  'penyelenggara,NN': 1,
#  'membeberkan,VB': 1,
#  'nama-nama,NN': 2,
#  'Salah satu,CD': 4,
#  'menghadiri,VB': 2,
#  'adalah,VB': 36,
#  'Chen,NNP': 1,
#  'Guangbiao,NNP': 1,
#  'seorang,NND': 6,
#  'meraup,VB': 1,
#  'bisnis,NN': 14,
#  'mendaur ulang,VB': 1,
#  'sampah,NN': 1,
#  'industri,NN': 28,
#  'bangunan,NN': 1,
#  'Dia,PRP': 21,
#  'BBC,NNP': 1,
#  'bahwa,SC': 38,
#  'dia,PRP': 56,
#  'seluruh,CD': 16,
#  'harta,NN': 1,
#  '#NAME?,PRP': 449,
#  'bila,SC': 4,
#  'meninggal,VB': 2,
#  'Beramal,VB': 1,
#  'membantu,VB': 10,
#  'menjadi,VB': 127,
#  'bagian,NN': 8,
#  'budaya,NN': 1,
#  'selama,IN': 21,
#  '5.000,CD': 1,
#  'tahun,NN': 168,
#  'Tetapi,CC': 2,
#  'resmi,JJ': 9,
#  'baru,MD': 11,
#  'dikembangkan,VB': 2,
#  'dalam,IN': 174,
#  '30,CD': 21,
#  'terakhir,JJ': 13,
#  'sejak,SC': 3,
#  'kami,PRP': 13,
#  'menerapkan,VB': 1,
#  'reformasi ekonomi,NN': 1,
#  'mulai,MD': 15,
#  'baru-baru ini,RB': 3,
#  'saja,RB': 12,
#  'memberi,VB': 4,
#  'makan,NN': 1,
#  'diri,NN': 3,
#  'sendiri,NN': 9,
#  'Menyumbangkan,VB': 1,
#  'uang,NN': 3,
#  'belum,NEG': 27,
#  'begitu,RB': 1,
#  'berkembang,VB': 4,
#  'sebaik,JJ': 2,
#  'Kalau,SC': 5,
#  'dikatakan,VB': 2,
#  'keberhasilan,NN': 2,
#  'mendorong,VB': 12,
#  'perdebatan,NN': 1,
#  'apa,SC': 2,
#  'arti,NN': 3,
#  'beramal,VB': 1,
#  'membutuhkan,VB': 5,
#  'Kisah,NN': 3,
#  'pendiri,NN': 2,
#  'Facebook,NNP': 5,
#  'dibuat,VB': 2,
#  'komik,NN': 2,
#  'Mark,NNP': 3,
#  'Zuckerberg,NNP': 6,
#  'diceritakan,VB': 1,
#  'sebuah,NND': 18,
#  'biografi,NN': 1,
#  'Komik,NN': 1,
#  'judul,NN': 3,
#  ':,Z': 5,
#  'Pencipta,NN': 1,
#  'tersedia,VB': 1,
#  'pasar,NN': 30,
#  'sebelum,SC': 42,
#  'Desember,NNP': 14,
#  '2010,CD': 4,
#  'demikian,PR': 20,
#  'pernyataan,NN': 9,
#  'penerbit,NNP': 1,
#  'Bluewater,NNP': 1,
#  'Productions,NNP': 1,
#  'Penulis,NNP': 1,
#  'Jerome,NNP': 1,
#  'Maida,NNP': 1,
#  'menyebut,VB': 1,
#  'kisah,NN': 2,
#  'mengagumkan,VB': 1,
#  'luar biasa,JJ': 2,
#  'Sebuah,NND': 1,
#  'film,NN': 7,
#  'The,NNP': 20,
#  'Social,NNP': 1,
#  'Network,NNP': 1,
#  'dirilis,VB': 1,
#  'pada,IN': 272,
#  'tanggal,NN': 11,
#  '15,CD': 18,
#  'Oktober,NNP': 29,
#  'nanti,NN': 5,
#  'Film,NN': 1,
#  'ditulis,VB': 4,
#  'oleh,IN': 87,
#  'pencipta,NN': 1,
#  'serial,NN': 1,
#  'West,NNP': 1,
#  'Wing,NNP': 1,
#  'Aaron,NNP': 1,
#  'Sorkin,NNP': 1,
#  'disutradarai,VB': 1,
#  'David,NNP': 1,
#  'Fincher,NNP': 1,
#  'pernah,MD': 7,
#  'menggarap,VB': 1,
#  'Fight,NNP': 1,
#  "',NNP": 5,
#  's,NNP': 5,
#  'Club,NNP': 1,
#  'sebenarnya,RB': 5,
#  'memperoleh,VB': 2,
#  'izin,NN': 2,
#  'Pemuda,NN': 1,
#  'berusia,VB': 7,
#  '26,CD': 6,
#  'Saya,PRP': 11,
#  'mengharapkan,VB': 5,
#  'ada,VB': 28,
#  'membuat,VB': 8,
#  'tentang,IN': 11,
#  'saya,PRP': 12,
#  'ketika,SC': 9,
#  'masih,MD': 62,
#  'hidup,VB': 1,
#  'konferensi,NN': 1,
#  'teknologi,NN': 7,
#  'Juni,NNP': 16,
#  'silam,NN': 2,
#  'Hingga,IN': 2,
#  'Juli,NNP': 13,
#  '500,CD': 5,
#  'juta,CD': 55,
#  'terdaftar,VB': 2,
#  'situs,NN': 7,
#  'jejaring,NN': 2,
#  'sosial,JJ': 3,
#  'Hanya,RB': 2,
#  'butuh,VB': 2,
#  'enam,CD': 8,
#  'kesuksesan,NN': 4,
#  'seperti,SC': 2,
#  'sekarang,NN': 5,
#  'setelah,SC': 24,
#  'meluncurkan,VB': 2,
#  'saat,SC': 5,
#  'duduk,VB': 2,
#  'sebagai,IN': 36,
#  'mahasiswa,NN': 1,
#  'Universitas,NNP': 2,
#  'Harvard,NNP': 2,
#  'September,NNP': 17,
#  'majalah,NNP': 2,
#  'Forbes,NNP': 1,
#  'memasukkan,VB': 2,
#  'daftar,NN': 2,
#  '35,CD': 6,
#  'Serikat,NNP': 7,
#  'dengan,SC': 53,
#  'total,NN': 20,
#  'diperkirakan,VB': 21,
#  'US,NNP': 8,
#  '$,SYM': 3,
#  '"6,4",CD': 4,
#  'miliar,CD': 120,
#  'langkah,NN': 7,
#  'menuju,VB': 4,
#  'lah,RP': 10,
#  'mulus,JJ': 2,
#  'orang,NND': 2,
#  'rekan,NN': 2,
#  'mengklaim,VB': 4,
#  'ide,NN': 1,
#  'pembuatan,NN': 4,
#  'datang,VB': 3,
#  'Mereka,PRP': 6,
#  'terlibat,VB': 1,
#  'sengketa,NN': 1,
#  'hukum,NN': 7,
#  'berlarut-larut,VB': 1,
#  '2008,CD': 43,
#  'diakhiri,VB': 1,
#  'pembayaran,NN': 10,
#  'dirahasiakan,VB': 1,
#  'jumlah,NN': 16,
#  'Cameron,NNP': 1,
#  'Tyler,NNP': 1,
#  'Winklevoss,NNP': 1,
#  'kini,NN': 5,
#  'bernama,VB': 3,
#  'ConnectU,NNP': 1,
#  'Perebutan,NN': 1,
#  'jamrud,NNP': 1,
#  'Bahia,NNP': 3,
#  'raksasa,JJ': 4,
#  'Jaksa,NN': 2,
#  'Kalifornia,NNP': 2,
#  'menanyai,VB': 1,
#  'menentukan,VB': 2,
#  'mengenai,SC': 1,
#  'kepemilikan,NN': 18,
#  'jamrud,NN': 4,
#  'disebut,VB': 4,
#  'terbesar,JJ': 11,
#  'Jamrud,NNP': 2,
#  'dinamakan,VB': 1,
#  'sesuai,JJ': 6,
#  'lokasi,NN': 1,
#  'penemuan,NN': 1,
#  'salah satu,CD': 7,
#  'daerah,NN': 12,
#  'Brasil,NNP': 6,
#  'berat,NN': 1,
#  '380,CD': 1,
#  'kg,NND': 2,
#  'Diperkirakan,VB': 1,
#  'bernilai,VB': 2,
#  '370,CD': 2,
#  'hak,NN': 3,
#  'atas,IN': 29,
#  'batu,NN': 5,
#  'mendengarkan,VB': 2,
#  'semua,CD': 10,
#  'permata,NN': 2,
#  'memutuskan,VB': 5,
#  'kasus,NN': 4,
#  'berselisih,VB': 1,
#  'Anthony,NNP': 1,
#  'Thomas,NNP': 3,
#  'ahli,NN': 1,
#  'konstruksi,NN': 7,
#  'membayar,VB': 5,
#  'agen,NN': 1,
#  'senilai,NN': 17,
#  '60,CD': 8,
#  'tak,NEG': 6,
#  'ditemukan,VB': 1,
#  'sembilan,CD': 6,
#  'lalu,NN': 1,
#  'mengatur,VB': 1,
#  'dikirim,VB': 2,
#  'melalui,IN': 21,
#  'kapal,NN': 6,
#  'ke,IN': 62,
#  'kediaman,NN': 1,
#  'San,NNP': 1,
#  'Jose,NNP': 1,
#  'tetapi,CC': 9,
#  'muncul,VB': 6,
#  'percaya,VB': 1,
#  'dicuri,VB': 1,
#  'dijual,VB': 3,
#  'kembali,RB': 26,
#  'harga,NN': 66,
#  'mahal,JJ': 2,
#  'hanya,RB': 23,
#  'pemilik,NN': 5,
#  'Satu,CD': 4,
#  'masalah,NN': 5,
#  'dihadapi,VB': 4,
#  'kehilangan,VB': 1,
#  'tanda terima,NN': 1,
#  'akibat,IN': 13,
#  'kebakaran,NN': 1,
#  'melanda,VB': 1,
#  'rumah,NN': 1,
#  'Jamrud,NN': 1,
#  'akhirnya,RB': 2,
#  'sampai,VB': 1,
#  'meskipun,SC': 4,
#  'setibanya,SC': 1,
#  'jelas,JJ': 3,
#  'siapa,SC': 3,
#  'hal,NN': 18,
#  'diketahui,VB': 1,
#  'sempat,MD': 7,
#  'disimpan,VB': 1,
#  'lemari besi,NN': 1,
#  'bank,NN': 25,
#  'New,NNP': 8,
#  'Orleans,NNP': 1,
#  'terkena,VB': 1,
#  'banjir,NN': 1,
#  'diterjang,VB': 1,
#  'Badai,NNP': 1,
#  'Katrina,NNP': 1,
#  'sehingga,SC': 30,
#  'berharga,JJ': 1,
#  'terendam,VB': 1,
#  'dalam,NN': 6,
#  'beberapa,CD': 20,
#  'bulan,NN': 44,
#  'kemudian,RB': 6,
#  'dibawa,VB': 1,
#  'Las,NNP': 1,
#  'Vegas,NNP': 1,
#  'dilihat,VB': 3,
#  'calon,NN': 3,
#  'pembeli,NN': 1,
#  'namun,CC': 21,
#  'disita,VB': 1,
#  'polisi,NN': 3,
#  'Los,NNP': 1,
#  'Angeles,NNP': 1,
#  'Badut,NN': 1,
#  'politikus,NN': 2,
#  'ditantang,VB': 2,
#  'baca,VB': 2,
#  'tulis,VB': 2,
#  'Seorang,NND': 4,
#  'badut,NN': 2,
#  'mempunyai,VB': 7,
#  'peluang,NN': 5,
#  'meraih,VB': 9,
#  'kursi,NN': 5,
#  'pemilihan,NN': 4,
#  'Minggu,NNP': 3,
#  '(,Z': 5,
#  '3,CD': 11,
#  '/,Z': 38,
#  '),Z': 5,
#  '-,Z': 104,
#  'membuktikan,VB': 3,
#  'membaca,VB': 5,
#  'menulis,VB': 1,
#  'Jajak,NN': 1,
#  'pendapat,NN': 1,
#  'memperlihatkan,VB': 7,
#  'Tiririca,NNP': 5,
#  'satu,CD': 11,
#  'suara,NN': 4,
#  'Namun,CC': 33,
#  'hakim,NN': 1,
#  'Sao,NNP': 1,
#  'Paulo,NNP': 1,
#  'menuntut,VB': 1,
#  'memenuhi,VB': 6,
#  'persyaratan,NN': 2,
#  'Sejumlah,CD': 1,
#  'surat kabar,NN': 1,
#  'sama,JJ': 38,
#  'seperti,IN': 19,
#  'sepuluh,CD': 5,
#  'buta aksara,JJ': 1,
#  'bahasa sehari-hari,NN': 1,
#  'Portugis,NNP': 1,
#  'tukang,NN': 1,
#  'mengeluh,VB': 1,
#  'sensasi,NN': 1,
#  'kampanye,NN': 2,
#  'Video,NN': 1,
#  'kocak,JJ': 1,
#  'jutaan,CD': 1,
#  'penonton,NN': 3,
#  'YouTube,NNP': 6,
#  'antara,IN': 22,
#  'menggunakan,VB': 11,
#  'slogan,NN': 1,
#  'Tidak,NEG': 1,
#  'buruk,JJ': 2,
#  'lagi,RB': 12,
#  'Apa,WH': 1,
#  'dilakukan,VB': 27,
#  'wakil,NN': 1,
#  'anda,PRP': 2,
#  '?,Z': 2,
#  'Sungguh,RB': 1,
#  'tahu,VB': 6,
#  'Tapi,CC': 4,
#  'pilih,VB': 1,
#  'mencari tahu,VB': 1,
#  'Hakim,NN': 1,
#  'menggelar,VB': 1,
#  'ujian,NN': 1,
#  'aksara,NN': 1,
#  'Epoca,NNP': 1,
#  'menayangkan,VB': 1,
#  'video,NN': 1,
#  'tampak,VB': 6,
#  'Komisi,NN': 1,
#  'terlambat,VB': 1,
#  'menghentikan,VB': 4,
#  'pencalonan,NN': 1,
#  'diberhentikan,VB': 1,
#  'jika,SC': 9,
#  'gagal,VB': 2,
#  'kemampuan,NN': 7,
#  'Calon,NN': 2,
#  'selebriti,NN': 3,
#  'nama,NN': 2,
#  'asli,JJ': 6,
#  'Francisco,NNP': 1,
#  'Everardo,NNP': 1,
#  'Oliveira,NNP': 1,
#  'Silva,NNP': 1,
#  'bekerja,VB': 5,
#  'sirkus,NN': 1,
#  'delapan,CD': 1,
#  'negara bagian,NN': 1,
#  'miskin,JJ': 1,
#  'Ceara,NNP': 1,
#  'Dengan,IN': 21,
#  'pengalaman,NN': 1,
#  'salah seorang,CD': 3,
#  'pelawak,NN': 1,
#  'terkenal,VB': 3,
#  'TV,NN': 5,
#  'merupakan,VB': 34,
#  'puluhan,CD': 1,
#  'berasal,VB': 10,
#  'olahraga,NN': 5,
#  'maupun,CC': 14,
#  'pertunjukan,NN': 1,
#  'berjuang,VB': 1,
#  'merebut,VB': 2,
#  'majelis rendah,NN': 1,
#  'bersaing,VB': 1,
#  'melawan,VB': 1,
#  'berpengalaman,VB': 1,
#  'Seluruhnya,RB': 1,
#  'tercatat,VB': 10,
#  '6,CD': 15,
#  '27,CD': 3,
#  'partai,NN': 1,
#  '513,CD': 1,
#  'diduga,VB': 2,
#  'kemenangan,NN': 2,
#  'mutlak,JJ': 1,
#  'Romario,NNP': 1,
#  'bintang,NN': 2,
#  'sepak bola,NN': 2,
#  'Piala,NNP': 3,
#  'Dunia,NNP': 17,
#  '1994,CD': 2,
#  'Para,DT': 3,
#  'pengamat,NN': 1,
#  'popularitas,NN': 1,
#  'mencerminkan,VB': 7,
#  'kebingungan,NN': 1,
#  'politik,NN': 1,
#  'utama,JJ': 9,
#  'karena,IN': 27,
#  'marak,JJ': 1,
#  'skandal,NN': 1,
#  'korupsi,NN': 4,
#  'Ibu,NN': 1,
#  'bayi,NN': 2,
#  'anggota,NN': 5,
#  'Parlemen,NNP': 2,
#  'Eropa,NNP': 4,
#  'asal,IN': 2,
#  'Italia,NNP': 2,
#  'sidang,NN': 4,
#  'Strasbourg,NNP': 1,
#  'menggendong,VB': 1,
#  'anak,NN': 6,
#  'Licia,NNP': 1,
#  'Ronzulli,NNP': 2,
#  'ia,PRP': 13,
#  'menunjukkan,VB': 19,
#  'berat,JJ': 5,
#  'beban,NN': 3,
#  'ditanggung,VB': 1,
#  'kaum,NN': 1,
#  'perempuan,NN': 2,
#  'menjalani,VB': 1,
#  'karir,NN': 1,
#  'sekaligus,RB': 4,
#  'mengasuh,VB': 1,
#  'sedang,MD': 8,
#  'membahas,VB': 3,
#  'usul,NN': 1,
#  'memperbaiki,VB': 9,
#  'kesempatan,NN': 6,
#  'Vittoria,NNP': 1,
#  'tidur,VB': 1,
#  'nyenyak,JJ': 1,
#  'selama,SC': 2,
#  'berlangsung,VB': 11,
#  'mewakili,VB': 2,
#  'Partai,NNP': 1,
#  'Kebebasan,NNP': 1,
#  'Rakyat,NNP': 1,
#  'pimpinan,NN': 2,
#  'PM,NNP': 5,
#  'Silvio,NNP': 1,
#  'Berlusconi,NNP': 1,
#  'mendapat,VB': 8,
#  'sambutan,NN': 1,
#  'meriah,JJ': 1,
#  'berdiri,VB': 1,
#  'menyampaikan,VB': 5,
#  'pidato,NN': 3,
#  'Ia,PRP': 25,
#  'sesama,NN': 1,
#  'melihat,VB': 9,
#  'komitmen,NN': 4,
#  'persoalan-persoalan,NN': 1,
#  'lembaga-lembaga,NN': 1,
#  'dimulai,VB': 2,
#  'Naskah,NN': 3,
#  'Harry,NNP': 3,
#  'Potter,NNP': 3,
#  'dipamerkan,VB': 4,
#  'tangan,NN': 1,
#  'pengarang,NN': 2,
#  'JK,NNP': 3,
#  'Rowling,NNP': 3,
#  'festival,NN': 3,
#  'buku,NN': 7,
#  'Skotlandia,NNP': 3,
#  'selatan,NNP': 1,
#  'halaman,NND': 1,
#  'naskah,NN': 3,
#  'dibingkai,VB': 1,
#  'ditandatangani,VB': 2,
#  'berisi,VB': 1,
#  'Balada,NN': 2,
#  'Nick,NNP': 3,
#  'Si,DT': 1,
#  'Kepala,NN': 8,
#  'Nyaris,RB': 2,
#  'Putus,VB': 2,
#  'Wigtown,NNP': 2,
#  '24,CD': 6,
#  'sampai,IN': 24,
#  'hantu,NN': 1,
#  'awal,NN': 19,
#  'Kamar,NN': 1,
#  'Rahasia,NN': 1,
#  'kemudian,CC': 6,
#  'kedua,CD': 8,
#  'halaman,NN': 5,
#  'dibuang,VB': 1,
#  'termasuk,VB': 20,
#  'diterbitkan,VB': 11,
#  'disumbangkan,VB': 2,
#  'Yayasan,NNP': 1,
#  'Kamus,NNP': 1,
#  'Bahasa,NNP': 2,
#  '2005,CD': 18,
#  'mendukung,VB': 10,
#  'pengumpulan,NN': 1,
#  'dana,NN': 26,
#  'kamus,NN': 1,
#  'baru,JJ': 15,
#  'bahasa,NN': 1,
#  'Sekarang,NN': 2,
#  'dimiliki,VB': 9,
#  'kolektor,NN': 1,
#  'terkemuka,JJ': 1,
#  'Inggris,NNP': 15,
#  'jurnal,NNP': 1,
#  'Asia,NNP': 12,
#  'Literary,NNP': 2,
#  'Review,NNP': 2,
#  'Ilyas,NNP': 2,
#  'Khan,NNP': 2,
#  'umum,NN': 1,
#  'senang,JJ': 1,
#  'ikut,VB': 2,
#  'Festival,NNP': 1,
#  'Memamerkan,VB': 1,
#  'si,DT': 3,
#  'cara,NN': 4,
#  'bagus,JJ': 4,
#  'Australia,NNP': 6,
#  'salah,JJ': 2,
#  'sebut,VB': 1,
#  'pemenang,NN': 6,
#  'Acara,NN': 1,
#  'Next,NNP': 1,
#  'Top,NNP': 1,
#  'Model,NNP': 1,
#  'mengumumkan,VB': 4,
#  'final,NN': 3,
#  'disiarkan,VB': 1,
#  'langsung,RB': 12,
#  'seri,NN': 9,
#  'keenam,OD': 3,
#  'Kelsey,NNP': 1,
#  'Martinovich,NNP': 2,
#  'dianugerahi,VB': 1,
#  'mahkota,NN': 1,
#  'pilihan,NN': 1,
#  'pemirsa,NN': 1,
#  'presenter,NNP': 1,
#  'Sarah,NNP': 4,
#  'Murdoch,NNP': 4,
#  'menyela,VB': 1,
#  'Sambil,SC': 1,
#  'menggeleng-gelengkan,VB': 1,
#  'kepala,NN': 1,
#  'ear,FW': 1,
#  'piece,FW': 1,
#  'mual,JJ': 1,
#  'amat,RB': 1,
#  'meminta,VB': 8,
#  'maaf,NN': 1,
#  'semata-mata,RB': 2,
#  'kecelakaan,NN': 1,
#  'yaitu,SC': 19,
#  'Amanda,NNP': 2,
#  'Ware,NNP': 2,
#  '18,CD': 8,
#  'Ini,PR': 10,
#  'terjadi,VB': 28,
#  'kalau,SC': 5,
#  'siaran,NN': 1,
#  'edan,JJ': 3,
#  'Adapun,CC': 1,
#  'sekitar,RB': 35,
#  'menit,NND': 1,
#  'menerima,VB': 5,
#  'kesalahan,NN': 1,
#  'baik,JJ': 28,
#  'Ok,FW': 1,
#  'kekeliruan,NN': 2,
#  'berusaha,VB': 3,
#  'menjelaskan,VB': 13,
#  'selisih,NN': 3,
#  'ketat,JJ': 4,
#  'Yang,DT': 3,
#  'memimpin,VB': 1,
#  'terus-menerus,RB': 2,
#  'berganti,VB': 1,
#  'Benar-benar,RB': 1,
#  'tergantung,VB': 3,
#  'Maju,VB': 1,
#  'mundur,VB': 1,
#  '-nya,PRP': 7,
#  'jelas,VB': 9,
#  'finalis,NN': 1,
#  'berpelukan,VB': 1,
#  'mengucapkan,VB': 1,
#  'terima kasih,NN': 1,
#  'pendukung,NN': 2,
#  'berjalan,VB': 10,
#  'atas,NN': 11,
#  'catwalk,FW': 1,
#  'terakhir,OD': 1,
#  'kali,NND': 6,
#  'Dan,CC': 2,
#  'model,NN': 2,
#  'merangkap,VB': 1,
#  'presenter,FW': 1,
#  'menikah,VB': 1,
#  'putra,NN': 1,
#  'Rupert,NNP': 1,
#  'Lachlan,NNP': 1,
#  'Membaca,VB': 1,
#  'Don,NNP': 3,
#  'Quixote,NNP': 3,
#  'Akademi,NNP': 2,
#  'Kerajaan,NNP': 4,
#  'Spanyol,NNP': 7,
#  'mengundang,VB': 1,
#  'merekam,VB': 1,
#  'segmen,NN': 8,
#  'novel,NN': 4,
#  'klasik,JJ': 2,
#  'mengunggah,VB': 1,
#  'Karya,NN': 1,
#  'Miguel,NNP': 1,
#  'de,NNP': 1,
#  'Cervantes,NNP': 1,
#  'paling,RB': 6,
#  'populer,JJ': 1,
#  'walau,SC': 1,
#  'pelindung,NN': 1,
#  'bahasa,NNP': 3,
#  'membagi,VB': 1,
#  'karya,NN': 3,
#  '2,CD': 7,
#  'Segmen-segmen,NN': 1,
#  'dibaca,VB': 1,
#  'direkam,VB': 1,
#  'sukarelawan,NN': 1,
#  'diunggah,VB': 2,
#  'Tujuan,NN': 1,
#  'mempromosikan,VB': 1,
#  'lengkap,JJ': 2,
#  'Ingenious,NNP': 1,
#  'Hidalgo,NNP': 1,
#  'of,NNP': 7,
#  'La,NNP': 1,
#  'Mancha,NNP': 2,
#  'ruang,NN': 2,
#  'sepatutnya,RB': 1,
#  'internet,NN': 1,
#  'sekretaris,NN': 1,
#  'akademi,NN': 1,
#  'Dario,NNP': 1,
#  'Villanueva,NNP': 1,
#  'Kami,PRP': 7,
#  'mengadukan,VB': 1,
#  'melakukan,VB': 30,
#  'sesuatu,PRP': 3,
#  'mengoreksi,VB': 1,
#  'Ditulis,VB': 1,
#  '1605,CD': 1,
#  'berkisah,VB': 1,
#  'petualangan,NN': 1,
#  'pria,NN': 3,
#  'pensiunan,NN': 1,
#  'kawasan,NN': 3,
#  'la,NNP': 1,
#  'punya,VB': 2,
#  'obsesi,NN': 1,
#  'gagasan-gagasan,NN': 1,
#  'kesatria,NN': 1,
#  'Novel,NN': 1,
#  'terdiri,VB': 18,
#  'bab,NN': 1,
#  'hampir,RB': 3,
#  '1,CD': 16,
#  'Bagi,IN': 1,
#  'berminat,VB': 1,
#  'mendaftarkan,VB': 1,
#  'terpilih,VB': 1,
#  'tertentu,JJ': 4,
#  'Hobbit,NNP': 3,
#  'cari,VB': 1,
#  'aktor,NN': 6,
#  'kerdil,JJ': 2,
#  'Tim,NN': 3,
#  'pembuat,NN': 2,
#  'mencari,VB': 5,
#  'Selandia,NNP': 2,
#  'Baru,NNP': 2,
#  'sementara,SC': 6,
#  'sutradara,NNP': 1,
#  'Peter,NNP': 2,
#  'Jackson,NNP': 3,
#  'berancang-ancang,VB': 1,
#  'merealisasikan,VB': 1,
#  'rencana,NN': 27,
#  'Sutradara,NNP': 1,
#  'Oscar,NNP': 2,
#  'Lord,NNP': 3,
#  'the,NNP': 4,
#  'Rings,NNP': 3,
#  ':,NNP': 2,
#  'Return,NNP': 2,
#  'King,NNP': 3,
#  'Iklan,NN': 1,
#  'koran,NN': 1,
#  'terbitan,NN': 1,
#  'Wellington,NNP': 2,
#  'Wingnut,NNP': 2,
#  'Films,NNP': 1,
#  'tinggi,NN': 5,
#  'badan,NN': 6,
#  '123,CD': 1,
#  'cm,NND': 5,
#  'maksimum,NN': 2,
#  '158,CD': 1,
#  'Proyek,NN': 1,
#  'lampu hijau,NN': 1,
#  'perusahaan,NN': 53,
#  'perfilman,NN': 1,
#  'MGM,NNP': 1,
#  'Studios,NNP': 1,
#  'kesulitan,NN': 2,
#  'keuangan,NN': 32,
#  'tengah,MD': 5,
#  'dialami,VB': 1,
#  'juru bicara,NNP': 1,
#  'bersiap-siap,VB': 1,
#  'Juru bicara,NN': 2,
#  'iklan,NN': 1,
#  'scale,FW': 1,
#  'double,FW': 3,
#  'mengisi,VB': 2,
#  'peran,NN': 2,
#  'dialog,NN': 3,
#  'sedangkan,CC': 21,
#  'audisi,NN': 1,
#  'diadakan,VB': 2,
#  'figuran,NN': 1,
#  'Scale,FW': 1,
#  'wide,FW': 1,
#  ...}

# %%
def create_trans_prob_table(tag_trans, tag_count):
    print(tag_trans)
    trans_prob = {}
    for tag1 in tag_count.keys():
        for tag2 in tag_count.keys():
            #print('tag1 = ')
            #print(tag1)
            trans_idx = tag1+','+tag2
            #print('trans_idx = ')
            #print(trans_idx)
            if trans_idx in tag_trans:
                #print(trans_idx)
                trans_prob[trans_idx] = tag_trans[trans_idx]/tag_count[tag1]
    return trans_prob

# %%
trans_prob = create_trans_prob_table(tag_trans, tag_count)
print(trans_prob)
# Out:
# {'<start>,NN': 321, 'NN,SC': 437, 'SC,VB': 496, 'VB,NN': 938, '<start>,NNP': 169, 'NNP,NNP': 1959, 'NNP,VB': 272, 'NN,JJ': 494, 'JJ,SC': 90, 'VB,RB': 65, 'RB,JJ': 137, 'JJ,IN': 154, 'IN,NN': 1280, 'NN,NNP': 509, 'NNP,Z': 743, '<start>,CD': 26, 'CD,NN': 432, 'NN,VB': 296, 'RB,CD': 40, 'VB,IN': 479, 'NN,NN': 2103, 'NN,CC': 238, 'CC,NN': 334, 'NN,IN': 533, 'IN,NNP': 440, 'VB,CD': 253, 'CC,VB': 86, 'VB,VB': 140, 'CD,Z': 434, 'Z,NN': 386, 'NN,PR': 324, 'PR,VB': 140, 'JJ,Z': 204, 'VB,JJ': 80, 'Z,VB': 331, 'Z,CC': 127, 'JJ,CC': 66, 'VB,PRP': 174, 'PRP,MD': 45, 'MD,VB': 408, 'SC,NN': 206, 'JJ,JJ': 29, 'JJ,VB': 74, 'VB,Z': 189, 'CC,FW': 19, 'FW,VB': 22, 'SC,RB': 74, 'RB,VB': 171, 'NN,Z': 504, 'JJ,MD': 20, 'IN,CD': 239, '<start>,Z': 26, 'PR,SC': 17, 'Z,Z': 54, 'VB,NNP': 158, 'NNP,IN': 261, '<start>,IN': 182, 'CC,RB': 37, '<start>,NEG': 1, 'NEG,JJ': 19, 'JJ,PR': 22, 'PR,NN': 31, 'PR,NEG': 15, 'NEG,MD': 22, 'VB,SC': 137, 'PRP,JJ': 11, '<start>,CC': 88, 'CC,MD': 17, 'Z,NNP': 338, 'NNP,RB': 40, 'SC,JJ': 76, 'NN,MD': 96, 'NNP,CC': 106, 'CC,NNP': 86, 'NNP,MD': 61, 'PRP,VB': 141, 'NNP,SC': 105, 'PR,Z': 144, 'PRP,RB': 30, 'VB,DT': 6, 'DT,NN': 15, 'CD,VB': 164, 'JJ,NN': 107, 'PR,MD': 49, 'NN,PRP': 206, 'PRP,Z': 223, '<start>,VB': 30, 'NN,NEG': 26, 'NEG,VB': 47, 'SC,MD': 79, 'Z,NND': 4, 'NND,NN': 60, '<start>,PRP': 72, 'SC,PRP': 65, 'PRP,IN': 91, 'VB,CC': 29, 'VB,MD': 39, 'Z,SC': 141, 'Z,CD': 77, 'MD,MD': 26, 'CC,PRP': 10, 'RB,RB': 12, 'RB,MD': 29, 'NEG,RB': 16, 'NNP,JJ': 23, '<start>,SC': 64, 'IN,SC': 9, 'IN,NND': 39, 'Z,MD': 19, 'SC,NNP': 41, 'NNP,CD': 159, 'Z,PR': 15, 'CC,Z': 38, 'Z,JJ': 21, '<start>,NND': 5, 'Z,RB': 23, 'NN,CD': 330, 'CD,NNP': 75, 'NNP,NN': 74, 'NNP,PR': 20, 'PR,RB': 35, 'RB,NEG': 5, 'Z,PRP': 37, 'VB,NEG': 8, 'IN,PRP': 41, 'PRP,SC': 38, 'CD,RB': 15, 'RB,IN': 42, 'CD,CD': 721, 'CD,SC': 46, '<start>,RB': 13, 'SC,SC': 16, 'PRP,PRP': 5, 'NNP,SYM': 5, 'SYM,CD': 278, 'NEG,RP': 4, 'RP,JJ': 2, 'CD,NND': 75, 'CD,CC': 101, 'NN,RB': 114, 'IN,JJ': 44, 'NND,Z': 26, 'CD,IN': 207, 'CC,NEG': 13, 'SC,IN': 27, 'NNP,NEG': 9, 'PRP,NN': 55, 'Z,NEG': 7, 'MD,RB': 46, 'JJ,RB': 21, 'RB,Z': 37, 'Z,WH': 2, 'WH,SC': 1, 'RB,PRP': 10, 'PRP,NEG': 12, 'VB,RP': 1, 'RP,PRP': 2, 'PRP,CC': 4, 'JJ,PRP': 59, 'PRP,NNP': 11, '<start>,DT': 4, 'NN,DT': 2, 'PRP,CD': 20, 'PR,IN': 31, 'JJ,NNP': 40, 'NNP,DT': 2, 'CC,CC': 9, 'CC,CD': 53, 'SC,NEG': 20, 'SC,OD': 4, 'OD,Z': 17, 'VB,FW': 36, 'FW,FW': 157, 'FW,PRP': 4, 'RB,NN': 38, 'PR,RP': 4, 'RP,SC': 4, 'PR,JJ': 16, 'IN,RB': 15, 'NND,VB': 10, 'Z,FW': 30, 'FW,Z': 58, 'Z,DT': 2, 'DT,VB': 3, 'RB,NNP': 8, 'IN,DT': 3, 'NN,FW': 92, 'FW,IN': 36, 'IN,OD': 4, 'OD,NND': 4, 'FW,NN': 43, 'NEG,CD': 3, 'Z,IN': 113, 'VB,PR': 8, 'NN,NND': 3, 'CC,SC': 16, 'NND,CC': 8, 'CD,FW': 10, 'NND,IN': 15, 'NND,CD': 4, 'CC,IN': 38, 'CC,JJ': 35, 'IN,X': 3, 'X,CD': 2, 'PR,CC': 10, 'SC,RP': 1, 'MD,Z': 3, 'JJ,FW': 12, 'FW,CC': 16, 'RB,SC': 8, 'NEG,NN': 11, 'PRP,WH': 1, 'WH,PRP': 1, 'CD,SYM': 15, 'SYM,IN': 11, 'SYM,VB': 3, 'NN,RP': 3, 'CD,PRP': 5, 'PRP,PR': 4, '<start>,PR': 17, 'SC,X': 2, 'X,JJ': 1, 'VB,SYM': 98, 'IN,FW': 27, 'NN,SYM': 59, 'NEG,Z': 3, 'FW,NNP': 26, 'JJ,CD': 114, 'NND,MD': 3, 'NN,OD': 79, 'CD,MD': 20, 'MD,CD': 2, 'IN,VB': 8, 'IN,PR': 38, 'JJ,OD': 3, 'OD,SC': 7, '<start>,UH': 3, 'UH,PRP': 1, 'RB,PR': 3, 'PR,PRP': 6, 'FW,PR': 10, 'MD,JJ': 28, 'SC,PR': 26, 'PR,NNP': 6, 'MD,NN': 8, 'JJ,SYM': 53, 'CD,JJ': 34, 'RB,CC': 2, 'OD,IN': 10, 'OD,CC': 4, 'NND,NND': 14, 'IN,SYM': 34, 'CD,PR': 12, 'NND,RB': 1, 'OD,VB': 5, 'OD,CD': 31, 'NNP,FW': 18, 'SC,CD': 15, 'Z,SYM': 27, 'SYM,Z': 26, 'SYM,JJ': 5, 'IN,Z': 15, 'FW,SC': 16, 'OD,JJ': 2, 'CC,PR': 7, 'SC,FW': 4, 'FW,CD': 5, 'SC,Z': 3, 'PR,FW': 3, 'CC,SYM': 9, 'PRP,RP': 2, 'RP,MD': 1, 'FW,RB': 3, 'PRP,X': 2, 'X,VB': 2, 'VB,X': 2, 'X,UH': 1, 'UH,SC': 1, 'VB,NND': 4, 'RB,FW': 6, 'MD,PRP': 3, 'MD,IN': 7, 'IN,NEG': 1, 'IN,IN': 22, 'PRP,SYM': 8, 'OD,SYM': 1, 'NNP,OD': 3, 'RB,SYM': 13, 'OD,MD': 1, 'WH,NN': 1, 'CC,WH': 1, 'WH,VB': 2, 'SYM,SYM': 3, '<start>,JJ': 4, 'NNP,PRP': 1, 'CD,NEG': 2, 'JJ,NEG': 2, 'RP,VB': 1, 'RP ...
# {'<start>,NN': 0.3116504854368932, '<start>,SC': 0.062135922330097085, '<start>,VB': 0.02912621359223301, '<start>,NNP': 0.16407766990291262, '<start>,JJ': 0.003883495145631068, '<start>,RB': 0.01262135922330097, '<start>,IN': 0.1766990291262136, '<start>,Z': 0.02524271844660194, '<start>,CD': 0.02524271844660194, '<start>,CC': 0.0854368932038835, '<start>,PR': 0.01650485436893204, '<start>,PRP': 0.06990291262135923, '<start>,MD': 0.000970873786407767, '<start>,FW': 0.002912621359223301, '<start>,NEG': 0.000970873786407767, '<start>,DT': 0.003883495145631068, '<start>,NND': 0.0048543689320388345, '<start>,WH': 0.000970873786407767, '<start>,UH': 0.002912621359223301, 'NN,NN': 0.3253403465346535, 'NN,SC': 0.06760519801980198, 'NN,VB': 0.04579207920792079, 'NN,NNP': 0.07874381188118812, 'NN,JJ': 0.07642326732673267, 'NN,RB': 0.017636138613861384, 'NN,IN': 0.08245668316831684, 'NN,Z': 0.07797029702970297, 'NN,CD': 0.0510519801980198, 'NN,CC': 0.03681930693069307, 'NN,PR': 0.05012376237623763, 'NN,PRP': 0.03186881188118812, 'NN,MD': 0.01485148514851485, 'NN,FW': 0.014232673267326733, 'NN,NEG': 0.004022277227722772, 'NN,DT': 0.0003094059405940594, 'NN,NND': 0.0004641089108910891, 'NN,SYM': 0.009127475247524752, 'NN,RP': 0.0004641089108910891, 'NN,WH': 0.0001547029702970297, 'NN,OD': 0.012221534653465347, 'NN,X': 0.0006188118811881188, 'SC,NN': 0.17789291882556132, 'SC,SC': 0.013816925734024179, 'SC,VB': 0.4283246977547496, 'SC,NNP': 0.03540587219343696, 'SC,JJ': 0.06563039723661486, 'SC,RB': 0.06390328151986183, 'SC,IN': 0.023316062176165803, 'SC,Z': 0.0025906735751295338, 'SC,CD': 0.012953367875647668, 'SC,CC': 0.0008635578583765112, 'SC,PR': 0.022452504317789293, 'SC,PRP': 0.05613126079447323, 'SC,MD': 0.06822107081174439, 'SC,FW': 0.0034542314335060447, 'SC,NEG': 0.017271157167530225, 'SC,SYM': 0.0008635578583765112, 'SC,RP': 0.0008635578583765112, 'SC,WH': 0.0008635578583765112, 'SC,OD': 0.0034542314335060447, 'SC,X': 0.0017271157167530224, 'VB,NN': 0.3288920056100982, 'VB,SC': 0.048036465638148666, 'VB,VB': 0.04908835904628331, 'VB,NNP': 0.05539971949509116, 'VB,JJ': 0.028050490883590462, 'VB,RB': 0.02279102384291725, 'VB,IN': 0.16795231416549788, 'VB,Z': 0.06626928471248247, 'VB,CD': 0.08870967741935484, 'VB,CC': 0.010168302945301542, 'VB,PR': 0.002805049088359046, 'VB,PRP': 0.061009817671809255, 'VB,MD': 0.01367461430575035, 'VB,FW': 0.012622720897615708, 'VB,NEG': 0.002805049088359046, 'VB,DT': 0.0021037868162692847, 'VB,NND': 0.001402524544179523, 'VB,SYM': 0.034361851332398316, 'VB,RP': 0.0003506311360448808, 'VB,OD': 0.0007012622720897616, 'VB,X': 0.0007012622720897616, 'NNP,NN': 0.019131334022750777, 'NNP,SC': 0.027145811789038264, 'NNP,VB': 0.0703205791106515, 'NNP,NNP': 0.5064632885211996, 'NNP,JJ': 0.0059462254395036196, 'NNP,RB': 0.010341261633919338, 'NNP,IN': 0.06747673216132369, 'NNP,Z': 0.1920889348500517, 'NNP,CD': 0.04110651499482937, 'NNP,CC': 0.027404343329886244, 'NNP,PR': 0.005170630816959669, 'NNP,PRP': 0.0002585315408479835, 'NNP,MD': 0.01577042399172699, 'NNP,FW': 0.004653567735263702, 'NNP,NEG': 0.002326783867631851, 'NNP,DT': 0.000517063081695967, 'NNP,SYM': 0.0012926577042399173, 'NNP,OD': 0.0007755946225439503, 'NNP,X': 0.0002585315408479835, 'JJ,NN': 0.09944237918215613, 'JJ,SC': 0.08364312267657993, 'JJ,VB': 0.0687732342007435, 'JJ,NNP': 0.03717472118959108, 'JJ,JJ': 0.02695167286245353, 'JJ,RB': 0.019516728624535316, 'JJ,IN': 0.14312267657992564, 'JJ,Z': 0.1895910780669145, 'JJ,CD': 0.10594795539033457, 'JJ,CC': 0.06133828996282528, 'JJ,PR': 0.020446096654275093, 'JJ,PRP': 0.05483271375464684, 'JJ,MD': 0.01858736059479554, 'JJ,FW': 0.011152416356877323, 'JJ,NEG': 0.0018587360594795538, 'JJ,SYM': 0.04925650557620818, 'JJ,RP': 0.0009293680297397769, 'JJ,WH': 0.0009293680297397769, 'JJ,OD': 0.0027881040892193307, 'RB,NN': 0.06761565836298933, 'RB,SC': 0.014234875444839857, 'RB,VB': 0.304270462633452, 'RB,NNP': 0.014234875444839857, 'RB,JJ': 0.24377224199288255, 'RB,RB': 0.021352313167259787, 'RB,IN' ...

# %%
def create_emission_prob_table(word_tag, tag_count):
    emission_prob = {}
    for word_tag_entry in word_tag.keys():
        word_tag_split = word_tag_entry.split(',')
        current_word = word_tag_split[0]
        current_tag = word_tag_split[1]
        if (len(word_tag_split)!=3):
            print(word_tag_entry)
            emission_prob[emission_key] = word_tag[word_tag_entry]/tag_count[current_tag] 
        else:
            emission_key = '","'+','+current_tag
            emission_prob[emission_key] = word_tag[emission_key]/tag_count[current_tag] 
    return emission_prob

# %%
emission_prob = create_emission_prob_table(word_tag, tag_count)
print(emission_prob)
# Out:
# Kera,NN
# Kera,NN
# untuk,SC
# untuk,SC
# amankan,VB
# amankan,VB
# pesta olahraga,NN
# pesta olahraga,NN
# Pemerintah,NNP
# Pemerintah,NNP
# kota,NNP
# kota,NNP
# Delhi,NNP
# Delhi,NNP
# mengerahkan,VB
# mengerahkan,VB
# monyet,NN
# monyet,NN
# mengusir,VB
# mengusir,VB
# monyet-monyet,NN
# monyet-monyet,NN
# lain,JJ
# lain,JJ
# yang,SC
# yang,SC
# berbadan,VB
# berbadan,VB
# lebih,RB
# lebih,RB
# kecil,JJ
# kecil,JJ
# dari,IN
# dari,IN
# arena,NN
# arena,NN
# Pesta Olahraga,NNP
# Pesta Olahraga,NNP
# Persemakmuran,NNP
# Persemakmuran,NNP
# .,Z
# .,Z
# Beberapa,CD
# Beberapa,CD
# laporan,NN
# laporan,NN
# menyebutkan,VB
# menyebutkan,VB
# setidaknya,RB
# setidaknya,RB
# 10,CD
# 10,CD
# ditempatkan,VB
# ditempatkan,VB
# di,IN
# di,IN
# luar,NN
# luar,NN
# lomba,NN
# lomba,NN
# dan,CC
# dan,CC
# pertandingan,NN
# pertandingan,NN
# ibukota,NNP
# ibukota,NNP
# India,NNP
# India,NNP
# Pemkot,NNP
# Pemkot,NNP
# memiliki,VB
# memiliki,VB
# 28,CD
# 28,CD
# berencana,VB
# berencana,VB
# mendatangkan,VB
# mendatangkan,VB
# sejenis,NN
# sejenis,NN
# negara bagian,NNP
# negara bagian,NNP
# Rajasthan,NNP
# Rajasthan,NNP
# Jumlah,NN
# Jumlah,NN
# mencapai,VB
# mencapai,VB
# ribuan,CD
# ribuan,CD
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-115-a50763e99f04> in <module>
# ----> 1 emission_prob = create_emission_prob_table(word_tag, tag_count)
#       2 print(emission_prob)
#
# <ipython-input-114-cd01eba83a20> in create_emission_prob_table(word_tag, tag_count)
#      12         else:
#      13             emission_key = '","'+','+current_tag
# ---> 14             emission_prob[emission_key] = word_tag[emission_key]/tag_count[current_tag]
#      15     return emission_prob
#
# KeyError: '",","'
